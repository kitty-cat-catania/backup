# %%
import os
import pandas as pd
from config import key_dict
import json
import requests
from census import Census
from us import states
import censusdata

# %%
base_call =  "api.census.gov/data/2019/acs/acs5?get=NAME,group(B01001)&for=us:1&key="

# %%
#Get my api key for census data
key = key_dict['census']
c = Census(key,year = 2015)

# %%
censusdata.search('acs5', 2015, 'concept', 'RACE')
# Out:
# [('B01001F_001E', 'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)', 'Total:'),
#  ('B01001F_001M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Total:'),
#  ('B01001F_002E', 'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)', 'Male:'),
#  ('B01001F_002M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:'),
#  ('B01001F_003E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!Under 5 years'),
#  ('B01001F_003M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!Under 5 years'),
#  ('B01001F_004E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!5 to 9 years'),
#  ('B01001F_004M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!5 to 9 years'),
#  ('B01001F_005E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!10 to 14 years'),
#  ('B01001F_005M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!10 to 14 years'),
#  ('B01001F_006E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!15 to 17 years'),
#  ('B01001F_006M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!15 to 17 years'),
#  ('B01001F_007E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!18 and 19 years'),
#  ('B01001F_007M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!18 and 19 years'),
#  ('B01001F_008E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!20 to 24 years'),
#  ('B01001F_008M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!20 to 24 years'),
#  ('B01001F_009E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!25 to 29 years'),
#  ('B01001F_009M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!25 to 29 years'),
#  ('B01001F_010E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!30 to 34 years'),
#  ('B01001F_010M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!30 to 34 years'),
#  ('B01001F_011E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!35 to 44 years'),
#  ('B01001F_011M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!35 to 44 years'),
#  ('B01001F_012E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!45 to 54 years'),
#  ('B01001F_012M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!45 to 54 years'),
#  ('B01001F_013E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!55 to 64 years'),
#  ('B01001F_013M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!55 to 64 years'),
#  ('B01001F_014E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!65 to 74 years'),
#  ('B01001F_014M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!65 to 74 years'),
#  ('B01001F_015E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!75 to 84 years'),
#  ('B01001F_015M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!75 to 84 years'),
#  ('B01001F_016E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Male:!!85 years and over'),
#  ('B01001F_016M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Male:!!85 years and over'),
#  ('B01001F_017E', 'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)', 'Female:'),
#  ('B01001F_017M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:'),
#  ('B01001F_018E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!Under 5 years'),
#  ('B01001F_018M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!Under 5 years'),
#  ('B01001F_019E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!5 to 9 years'),
#  ('B01001F_019M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!5 to 9 years'),
#  ('B01001F_020E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!10 to 14 years'),
#  ('B01001F_020M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!10 to 14 years'),
#  ('B01001F_021E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!15 to 17 years'),
#  ('B01001F_021M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!15 to 17 years'),
#  ('B01001F_022E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!18 and 19 years'),
#  ('B01001F_022M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!18 and 19 years'),
#  ('B01001F_023E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!20 to 24 years'),
#  ('B01001F_023M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!20 to 24 years'),
#  ('B01001F_024E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!25 to 29 years'),
#  ('B01001F_024M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!25 to 29 years'),
#  ('B01001F_025E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!30 to 34 years'),
#  ('B01001F_025M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!30 to 34 years'),
#  ('B01001F_026E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!35 to 44 years'),
#  ('B01001F_026M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!35 to 44 years'),
#  ('B01001F_027E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!45 to 54 years'),
#  ('B01001F_027M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!45 to 54 years'),
#  ('B01001F_028E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!55 to 64 years'),
#  ('B01001F_028M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!55 to 64 years'),
#  ('B01001F_029E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!65 to 74 years'),
#  ('B01001F_029M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!65 to 74 years'),
#  ('B01001F_030E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!75 to 84 years'),
#  ('B01001F_030M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!75 to 84 years'),
#  ('B01001F_031E',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Female:!!85 years and over'),
#  ('B01001F_031M',
#   'B01001F.  SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Female:!!85 years and over'),
#  ('B01001G_001E', 'B01001G.  SEX BY AGE (TWO OR MORE RACES)', 'Total:'),
#  ('B01001G_001M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Total:'),
#  ('B01001G_002E', 'B01001G.  SEX BY AGE (TWO OR MORE RACES)', 'Male:'),
#  ('B01001G_002M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:'),
#  ('B01001G_003E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!Under 5 years'),
#  ('B01001G_003M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!Under 5 years'),
#  ('B01001G_004E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!5 to 9 years'),
#  ('B01001G_004M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!5 to 9 years'),
#  ('B01001G_005E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!10 to 14 years'),
#  ('B01001G_005M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!10 to 14 years'),
#  ('B01001G_006E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!15 to 17 years'),
#  ('B01001G_006M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!15 to 17 years'),
#  ('B01001G_007E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!18 and 19 years'),
#  ('B01001G_007M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!18 and 19 years'),
#  ('B01001G_008E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!20 to 24 years'),
#  ('B01001G_008M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!20 to 24 years'),
#  ('B01001G_009E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!25 to 29 years'),
#  ('B01001G_009M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!25 to 29 years'),
#  ('B01001G_010E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!30 to 34 years'),
#  ('B01001G_010M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!30 to 34 years'),
#  ('B01001G_011E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!35 to 44 years'),
#  ('B01001G_011M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!35 to 44 years'),
#  ('B01001G_012E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!45 to 54 years'),
#  ('B01001G_012M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!45 to 54 years'),
#  ('B01001G_013E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!55 to 64 years'),
#  ('B01001G_013M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!55 to 64 years'),
#  ('B01001G_014E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!65 to 74 years'),
#  ('B01001G_014M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!65 to 74 years'),
#  ('B01001G_015E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!75 to 84 years'),
#  ('B01001G_015M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!75 to 84 years'),
#  ('B01001G_016E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Male:!!85 years and over'),
#  ('B01001G_016M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Male:!!85 years and over'),
#  ('B01001G_017E', 'B01001G.  SEX BY AGE (TWO OR MORE RACES)', 'Female:'),
#  ('B01001G_017M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:'),
#  ('B01001G_018E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!Under 5 years'),
#  ('B01001G_018M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!Under 5 years'),
#  ('B01001G_019E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!5 to 9 years'),
#  ('B01001G_019M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!5 to 9 years'),
#  ('B01001G_020E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!10 to 14 years'),
#  ('B01001G_020M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!10 to 14 years'),
#  ('B01001G_021E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!15 to 17 years'),
#  ('B01001G_021M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!15 to 17 years'),
#  ('B01001G_022E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!18 and 19 years'),
#  ('B01001G_022M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!18 and 19 years'),
#  ('B01001G_023E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!20 to 24 years'),
#  ('B01001G_023M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!20 to 24 years'),
#  ('B01001G_024E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!25 to 29 years'),
#  ('B01001G_024M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!25 to 29 years'),
#  ('B01001G_025E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!30 to 34 years'),
#  ('B01001G_025M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!30 to 34 years'),
#  ('B01001G_026E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!35 to 44 years'),
#  ('B01001G_026M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!35 to 44 years'),
#  ('B01001G_027E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!45 to 54 years'),
#  ('B01001G_027M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!45 to 54 years'),
#  ('B01001G_028E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!55 to 64 years'),
#  ('B01001G_028M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!55 to 64 years'),
#  ('B01001G_029E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!65 to 74 years'),
#  ('B01001G_029M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!65 to 74 years'),
#  ('B01001G_030E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!75 to 84 years'),
#  ('B01001G_030M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!75 to 84 years'),
#  ('B01001G_031E',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Female:!!85 years and over'),
#  ('B01001G_031M',
#   'B01001G.  SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Female:!!85 years and over'),
#  ('B01002F_001E',
#   'B01002F.  MEDIAN AGE BY SEX (SOME OTHER RACE ALONE)',
#   'Median age --!!Total:'),
#  ('B01002F_001M',
#   'B01002F.  MEDIAN AGE BY SEX (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Median age --!!Total:'),
#  ('B01002F_002E',
#   'B01002F.  MEDIAN AGE BY SEX (SOME OTHER RACE ALONE)',
#   'Median age --!!Male'),
#  ('B01002F_002M',
#   'B01002F.  MEDIAN AGE BY SEX (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Median age --!!Male'),
#  ('B01002F_003E',
#   'B01002F.  MEDIAN AGE BY SEX (SOME OTHER RACE ALONE)',
#   'Median age --!!Female'),
#  ('B01002F_003M',
#   'B01002F.  MEDIAN AGE BY SEX (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Median age --!!Female'),
#  ('B01002G_001E',
#   'B01002G.  MEDIAN AGE BY SEX (TWO OR MORE RACES)',
#   'Median age --!!Total:'),
#  ('B01002G_001M',
#   'B01002G.  MEDIAN AGE BY SEX (TWO OR MORE RACES)',
#   'Margin Of Error For!!Median age --!!Total:'),
#  ('B01002G_002E',
#   'B01002G.  MEDIAN AGE BY SEX (TWO OR MORE RACES)',
#   'Median age --!!Male'),
#  ('B01002G_002M',
#   'B01002G.  MEDIAN AGE BY SEX (TWO OR MORE RACES)',
#   'Margin Of Error For!!Median age --!!Male'),
#  ('B01002G_003E',
#   'B01002G.  MEDIAN AGE BY SEX (TWO OR MORE RACES)',
#   'Median age --!!Female'),
#  ('B01002G_003M',
#   'B01002G.  MEDIAN AGE BY SEX (TWO OR MORE RACES)',
#   'Margin Of Error For!!Median age --!!Female'),
#  ('B02001_001E', 'B02001.  Race', 'Total:'),
#  ('B02001_001M', 'B02001.  Race', 'Margin Of Error For!!Total:'),
#  ('B02001_002E', 'B02001.  Race', 'White alone'),
#  ('B02001_002M', 'B02001.  Race', 'Margin Of Error For!!White alone'),
#  ('B02001_003E', 'B02001.  Race', 'Black or African American alone'),
#  ('B02001_003M',
#   'B02001.  Race',
#   'Margin Of Error For!!Black or African American alone'),
#  ('B02001_004E', 'B02001.  Race', 'American Indian and Alaska Native alone'),
#  ('B02001_004M',
#   'B02001.  Race',
#   'Margin Of Error For!!American Indian and Alaska Native alone'),
#  ('B02001_005E', 'B02001.  Race', 'Asian alone'),
#  ('B02001_005M', 'B02001.  Race', 'Margin Of Error For!!Asian alone'),
#  ('B02001_006E',
#   'B02001.  Race',
#   'Native Hawaiian and Other Pacific Islander alone'),
#  ('B02001_006M',
#   'B02001.  Race',
#   'Margin Of Error For!!Native Hawaiian and Other Pacific Islander alone'),
#  ('B02001_007E', 'B02001.  Race', 'Some other race alone'),
#  ('B02001_007M',
#   'B02001.  Race',
#   'Margin Of Error For!!Some other race alone'),
#  ('B02001_008E', 'B02001.  Race', 'Two or more races:'),
#  ('B02001_008M', 'B02001.  Race', 'Margin Of Error For!!Two or more races:'),
#  ('B02001_009E',
#   'B02001.  Race',
#   'Two or more races:!!Two races including Some other race'),
#  ('B02001_009M',
#   'B02001.  Race',
#   'Margin Of Error For!!Two or more races:!!Two races including Some other race'),
#  ('B02001_010E',
#   'B02001.  Race',
#   'Two or more races:!!Two races excluding Some other race, and three or more races'),
#  ('B02001_010M',
#   'B02001.  Race',
#   'Margin Of Error For!!Two or more races:!!Two races excluding Some other race, and three or more races'),
#  ('B02008_001E',
#   'B02008.  White Alone Or In Combination With One Or More Other Races',
#   'Total:'),
#  ('B02008_001M',
#   'B02008.  White Alone Or In Combination With One Or More Other Races',
#   'Margin Of Error For!!Total:'),
#  ('B02009_001E',
#   'B02009.  Black Or African American Alone Or In Combination With One Or More Other Races',
#   'Total:'),
#  ('B02009_001M',
#   'B02009.  Black Or African American Alone Or In Combination With One Or More Other Races',
#   'Margin Of Error For!!Total:'),
#  ('B02010_001E',
#   'B02010.  American Indian And Alaska Native Alone Or In Combination With One Or More Other Races',
#   'Total:'),
#  ('B02010_001M',
#   'B02010.  American Indian And Alaska Native Alone Or In Combination With One Or More Other Races',
#   'Margin Of Error For!!Total:'),
#  ('B02011_001E',
#   'B02011.  Asian Alone Or In Combination With One Or More Other Races',
#   'Total:'),
#  ('B02011_001M',
#   'B02011.  Asian Alone Or In Combination With One Or More Other Races',
#   'Margin Of Error For!!Total:'),
#  ('B02012_001E',
#   'B02012.  Native Hawaiian And Other Pacific Islander Alone Or In Combination With One Or More Other Races',
#   'Total:'),
#  ('B02012_001M',
#   'B02012.  Native Hawaiian And Other Pacific Islander Alone Or In Combination With One Or More Other Races',
#   'Margin Of Error For!!Total:'),
#  ('B02013_001E',
#   'B02013.  Some Other Race Alone Or In Combination With One Or More Other Races',
#   'Total:'),
#  ('B02013_001M',
#   'B02013.  Some Other Race Alone Or In Combination With One Or More Other Races',
#   'Margin Of Error For!!Total:'),
#  ('B03002_001E', 'B03002.  Hispanic or Latino by Race', 'Total:'),
#  ('B03002_001M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Total:'),
#  ('B03002_002E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:'),
#  ('B03002_002M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:'),
#  ('B03002_003E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!White alone'),
#  ('B03002_003M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!White alone'),
#  ('B03002_004E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!Black or African American alone'),
#  ('B03002_004M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!Black or African American alone'),
#  ('B03002_005E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!American Indian and Alaska Native alone'),
#  ('B03002_005M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!American Indian and Alaska Native alone'),
#  ('B03002_006E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!Asian alone'),
#  ('B03002_006M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!Asian alone'),
#  ('B03002_007E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!Native Hawaiian and Other Pacific Islander alone'),
#  ('B03002_007M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!Native Hawaiian and Other Pacific Islander alone'),
#  ('B03002_008E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!Some other race alone'),
#  ('B03002_008M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!Some other race alone'),
#  ('B03002_009E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!Two or more races:'),
#  ('B03002_009M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!Two or more races:'),
#  ('B03002_010E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!Two or more races:!!Two races including Some other race'),
#  ('B03002_010M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!Two or more races:!!Two races including Some other race'),
#  ('B03002_011E',
#   'B03002.  Hispanic or Latino by Race',
#   'Not Hispanic or Latino:!!Two or more races:!!Two races excluding Some other race, and three or more races'),
#  ('B03002_011M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Not Hispanic or Latino:!!Two or more races:!!Two races excluding Some other race, and three or more races'),
#  ('B03002_012E', 'B03002.  Hispanic or Latino by Race', 'Hispanic or Latino:'),
#  ('B03002_012M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:'),
#  ('B03002_013E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!White alone'),
#  ('B03002_013M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!White alone'),
#  ('B03002_014E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!Black or African American alone'),
#  ('B03002_014M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!Black or African American alone'),
#  ('B03002_015E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!American Indian and Alaska Native alone'),
#  ('B03002_015M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!American Indian and Alaska Native alone'),
#  ('B03002_016E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!Asian alone'),
#  ('B03002_016M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!Asian alone'),
#  ('B03002_017E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!Native Hawaiian and Other Pacific Islander alone'),
#  ('B03002_017M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!Native Hawaiian and Other Pacific Islander alone'),
#  ('B03002_018E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!Some other race alone'),
#  ('B03002_018M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!Some other race alone'),
#  ('B03002_019E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!Two or more races:'),
#  ('B03002_019M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!Two or more races:'),
#  ('B03002_020E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!Two or more races:!!Two races including Some other race'),
#  ('B03002_020M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!Two or more races:!!Two races including Some other race'),
#  ('B03002_021E',
#   'B03002.  Hispanic or Latino by Race',
#   'Hispanic or Latino:!!Two or more races:!!Two races excluding Some other race, and three or more races'),
#  ('B03002_021M',
#   'B03002.  Hispanic or Latino by Race',
#   'Margin Of Error For!!Hispanic or Latino:!!Two or more races:!!Two races excluding Some other race, and three or more races'),
#  ('B05003F_001E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Total:'),
#  ('B05003F_001M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Total:'),
#  ('B05003F_002E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:'),
#  ('B05003F_002M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:'),
#  ('B05003F_003E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!Under 18 years:'),
#  ('B05003F_003M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!Under 18 years:'),
#  ('B05003F_004E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!Under 18 years:!!Native'),
#  ('B05003F_004M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!Under 18 years:!!Native'),
#  ('B05003F_005E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!Under 18 years:!!Foreign born:'),
#  ('B05003F_005M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!Under 18 years:!!Foreign born:'),
#  ('B05003F_006E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!Under 18 years:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003F_006M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!Under 18 years:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003F_007E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!Under 18 years:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003F_007M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!Under 18 years:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003F_008E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!18 years and over:'),
#  ('B05003F_008M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!18 years and over:'),
#  ('B05003F_009E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!18 years and over:!!Native'),
#  ('B05003F_009M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!18 years and over:!!Native'),
#  ('B05003F_010E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!18 years and over:!!Foreign born:'),
#  ('B05003F_010M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!18 years and over:!!Foreign born:'),
#  ('B05003F_011E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!18 years and over:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003F_011M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!18 years and over:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003F_012E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Male:!!18 years and over:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003F_012M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Male:!!18 years and over:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003F_013E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:'),
#  ('B05003F_013M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:'),
#  ('B05003F_014E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!Under 18 years:'),
#  ('B05003F_014M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!Under 18 years:'),
#  ('B05003F_015E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!Under 18 years:!!Native'),
#  ('B05003F_015M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!Under 18 years:!!Native'),
#  ('B05003F_016E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!Under 18 years:!!Foreign born:'),
#  ('B05003F_016M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!Under 18 years:!!Foreign born:'),
#  ('B05003F_017E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!Under 18 years:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003F_017M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!Under 18 years:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003F_018E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!Under 18 years:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003F_018M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!Under 18 years:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003F_019E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!18 years and over:'),
#  ('B05003F_019M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!18 years and over:'),
#  ('B05003F_020E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!18 years and over:!!Native'),
#  ('B05003F_020M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!18 years and over:!!Native'),
#  ('B05003F_021E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!18 years and over:!!Foreign born:'),
#  ('B05003F_021M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!18 years and over:!!Foreign born:'),
#  ('B05003F_022E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!18 years and over:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003F_022M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!18 years and over:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003F_023E',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Female:!!18 years and over:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003F_023M',
#   'B05003F.  Sex by Age by Nativity and Citizenship Status  (Some Other Race Alone)',
#   'Margin Of Error For!!Female:!!18 years and over:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003G_001E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Total:'),
#  ('B05003G_001M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Total:'),
#  ('B05003G_002E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:'),
#  ('B05003G_002M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:'),
#  ('B05003G_003E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!Under 18 years:'),
#  ('B05003G_003M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!Under 18 years:'),
#  ('B05003G_004E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!Under 18 years:!!Native'),
#  ('B05003G_004M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!Under 18 years:!!Native'),
#  ('B05003G_005E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!Under 18 years:!!Foreign born:'),
#  ('B05003G_005M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!Under 18 years:!!Foreign born:'),
#  ('B05003G_006E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!Under 18 years:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003G_006M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!Under 18 years:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003G_007E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!Under 18 years:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003G_007M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!Under 18 years:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003G_008E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!18 years and over:'),
#  ('B05003G_008M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!18 years and over:'),
#  ('B05003G_009E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!18 years and over:!!Native'),
#  ('B05003G_009M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!18 years and over:!!Native'),
#  ('B05003G_010E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!18 years and over:!!Foreign born:'),
#  ('B05003G_010M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!18 years and over:!!Foreign born:'),
#  ('B05003G_011E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!18 years and over:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003G_011M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!18 years and over:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003G_012E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Male:!!18 years and over:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003G_012M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Male:!!18 years and over:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003G_013E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:'),
#  ('B05003G_013M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:'),
#  ('B05003G_014E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!Under 18 years:'),
#  ('B05003G_014M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!Under 18 years:'),
#  ('B05003G_015E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!Under 18 years:!!Native'),
#  ('B05003G_015M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!Under 18 years:!!Native'),
#  ('B05003G_016E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!Under 18 years:!!Foreign born:'),
#  ('B05003G_016M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!Under 18 years:!!Foreign born:'),
#  ('B05003G_017E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!Under 18 years:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003G_017M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!Under 18 years:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003G_018E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!Under 18 years:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003G_018M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!Under 18 years:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003G_019E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!18 years and over:'),
#  ('B05003G_019M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!18 years and over:'),
#  ('B05003G_020E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!18 years and over:!!Native'),
#  ('B05003G_020M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!18 years and over:!!Native'),
#  ('B05003G_021E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!18 years and over:!!Foreign born:'),
#  ('B05003G_021M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!18 years and over:!!Foreign born:'),
#  ('B05003G_022E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!18 years and over:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003G_022M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!18 years and over:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B05003G_023E',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Female:!!18 years and over:!!Foreign born:!!Not a U.S. citizen'),
#  ('B05003G_023M',
#   'B05003G.  Sex by Age by Nativity and Citizenship Status (Two or More Races )',
#   'Margin Of Error For!!Female:!!18 years and over:!!Foreign born:!!Not a U.S. citizen'),
#  ('B06004FPR_001E',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Total:'),
#  ('B06004FPR_001M',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Margin Of Error For!!Total:'),
#  ('B06004FPR_002E',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Born in Puerto Rico'),
#  ('B06004FPR_002M',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Margin Of Error For!!Born in Puerto Rico'),
#  ('B06004FPR_003E',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Born in the United States'),
#  ('B06004FPR_003M',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Margin Of Error For!!Born in the United States'),
#  ('B06004FPR_004E',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Native; born elsewhere'),
#  ('B06004FPR_004M',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Margin Of Error For!!Native; born elsewhere'),
#  ('B06004FPR_005E',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Foreign born'),
#  ('B06004FPR_005M',
#   'B06004FPR.  Place of Birth (Some Other Race Alone) in Puerto Rico',
#   'Margin Of Error For!!Foreign born'),
#  ('B06004F_001E',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Total:'),
#  ('B06004F_001M',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Margin Of Error For!!Total:'),
#  ('B06004F_002E',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Born in state of residence'),
#  ('B06004F_002M',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Margin Of Error For!!Born in state of residence'),
#  ('B06004F_003E',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Born in other state in the United States'),
#  ('B06004F_003M',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Margin Of Error For!!Born in other state in the United States'),
#  ('B06004F_004E',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Native; born outside the United States'),
#  ('B06004F_004M',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Margin Of Error For!!Native; born outside the United States'),
#  ('B06004F_005E',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Foreign born'),
#  ('B06004F_005M',
#   'B06004F.  Place of Birth (Some Other Race Alone) in the United States',
#   'Margin Of Error For!!Foreign born'),
#  ('B06004GPR_001E',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Total:'),
#  ('B06004GPR_001M',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Margin Of Error For!!Total:'),
#  ('B06004GPR_002E',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Born in Puerto Rico'),
#  ('B06004GPR_002M',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Margin Of Error For!!Born in Puerto Rico'),
#  ('B06004GPR_003E',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Born in the United States'),
#  ('B06004GPR_003M',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Margin Of Error For!!Born in the United States'),
#  ('B06004GPR_004E',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Native; born elsewhere'),
#  ('B06004GPR_004M',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Margin Of Error For!!Native; born elsewhere'),
#  ('B06004GPR_005E',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Foreign born'),
#  ('B06004GPR_005M',
#   'B06004GPR.  Place of Birth (Two or More Races) in Puerto Rico',
#   'Margin Of Error For!!Foreign born'),
#  ('B06004G_001E',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Total:'),
#  ('B06004G_001M',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Margin Of Error For!!Total:'),
#  ('B06004G_002E',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Born in state of residence'),
#  ('B06004G_002M',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Margin Of Error For!!Born in state of residence'),
#  ('B06004G_003E',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Born in other state in the United States'),
#  ('B06004G_003M',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Margin Of Error For!!Born in other state in the United States'),
#  ('B06004G_004E',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Native; born outside the United States'),
#  ('B06004G_004M',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Margin Of Error For!!Native; born outside the United States'),
#  ('B06004G_005E',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Foreign born'),
#  ('B06004G_005M',
#   'B06004G.  Place of Birth (Two or More Races) in the United States',
#   'Margin Of Error For!!Foreign born'),
#  ('B07004FPR_001E',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Total:'),
#  ('B07004FPR_001M',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Total:'),
#  ('B07004FPR_002E',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Same house 1 year ago'),
#  ('B07004FPR_002M',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Same house 1 year ago'),
#  ('B07004FPR_003E',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Moved within same municipio'),
#  ('B07004FPR_003M',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Moved within same municipio'),
#  ('B07004FPR_004E',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Moved from different municipio'),
#  ('B07004FPR_004M',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Moved from different municipio'),
#  ('B07004FPR_005E',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Moved from the United States'),
#  ('B07004FPR_005M',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Moved from the United States'),
#  ('B07004FPR_006E',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Moved from elsewhere'),
#  ('B07004FPR_006M',
#   'B07004FPR.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Moved from elsewhere'),
#  ('B07004F_001E',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Total:'),
#  ('B07004F_001M',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Margin Of Error For!!Total:'),
#  ('B07004F_002E',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Same house 1 year ago'),
#  ('B07004F_002M',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Margin Of Error For!!Same house 1 year ago'),
#  ('B07004F_003E',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Moved within same county'),
#  ('B07004F_003M',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Margin Of Error For!!Moved within same county'),
#  ('B07004F_004E',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Moved from different county within same state'),
#  ('B07004F_004M',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Margin Of Error For!!Moved from different county within same state'),
#  ('B07004F_005E',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Moved from different state'),
#  ('B07004F_005M',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Margin Of Error For!!Moved from different state'),
#  ('B07004F_006E',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Moved from abroad'),
#  ('B07004F_006M',
#   'B07004F.  Geographical Mobility in the Past Year (Some Other Race Alone) for Current Residence in the U.S.',
#   'Margin Of Error For!!Moved from abroad'),
#  ('B07004GPR_001E',
#   'B07004GPR.  Geographical Mobility in the Past Year (Two or More Races) for Current Residence in Puerto Rico',
#   'Total:'),
#  ('B07004GPR_001M',
#   'B07004GPR.  Geographical Mobility in the Past Year (Two or More Races) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Total:'),
#  ('B07004GPR_002E',
#   'B07004GPR.  Geographical Mobility in the Past Year (Two or More Races) for Current Residence in Puerto Rico',
#   'Same house 1 year ago'),
#  ('B07004GPR_002M',
#   'B07004GPR.  Geographical Mobility in the Past Year (Two or More Races) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Same house 1 year ago'),
#  ('B07004GPR_003E',
#   'B07004GPR.  Geographical Mobility in the Past Year (Two or More Races) for Current Residence in Puerto Rico',
#   'Moved within same municipio'),
#  ('B07004GPR_003M',
#   'B07004GPR.  Geographical Mobility in the Past Year (Two or More Races) for Current Residence in Puerto Rico',
#   'Margin Of Error For!!Moved within same municipio'),
#  ('B07004GPR_004E',
#   'B07004GPR.  Geographical Mobility in the Past Year (Two or More Races) for Current Residence in Puerto Rico',
#   'Moved from different municipio'),
#  ('B07004GPR_004M',
#   'B07004GPR.  Geographical Mobility in the Past Year (Two or More Races) for Current Residence in Puerto Rico',
# ...
#  ('B17001F_056M',
#   'B17001F.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Female:!!45 to 54 years'),
#  ('B17001F_057E',
#   'B17001F.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Income in the past 12 months at or above poverty level:!!Female:!!55 to 64 years'),
#  ('B17001F_057M',
#   'B17001F.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Female:!!55 to 64 years'),
#  ('B17001F_058E',
#   'B17001F.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Income in the past 12 months at or above poverty level:!!Female:!!65 to 74 years'),
#  ('B17001F_058M',
#   'B17001F.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Female:!!65 to 74 years'),
#  ('B17001F_059E',
#   'B17001F.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Income in the past 12 months at or above poverty level:!!Female:!!75 years and over'),
#  ('B17001F_059M',
#   'B17001F.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (SOME OTHER RACE ALONE)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Female:!!75 years and over'),
#  ('B17001G_001E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Total:'),
#  ('B17001G_001M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Total:'),
#  ('B17001G_002E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:'),
#  ('B17001G_002M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:'),
#  ('B17001G_003E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:'),
#  ('B17001G_003M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:'),
#  ('B17001G_004E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!Under 5 years'),
#  ('B17001G_004M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!Under 5 years'),
#  ('B17001G_005E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!5 years'),
#  ('B17001G_005M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!5 years'),
#  ('B17001G_006E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!6 to 11 years'),
#  ('B17001G_006M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!6 to 11 years'),
#  ('B17001G_007E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!12 to 14 years'),
#  ('B17001G_007M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!12 to 14 years'),
#  ('B17001G_008E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!15 years'),
#  ('B17001G_008M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!15 years'),
#  ('B17001G_009E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!16 and 17 years'),
#  ('B17001G_009M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!16 and 17 years'),
#  ('B17001G_010E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!18 to 24 years'),
#  ('B17001G_010M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!18 to 24 years'),
#  ('B17001G_011E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!25 to 34 years'),
#  ('B17001G_011M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!25 to 34 years'),
#  ('B17001G_012E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!35 to 44 years'),
#  ('B17001G_012M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!35 to 44 years'),
#  ('B17001G_013E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!45 to 54 years'),
#  ('B17001G_013M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!45 to 54 years'),
#  ('B17001G_014E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!55 to 64 years'),
#  ('B17001G_014M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!55 to 64 years'),
#  ('B17001G_015E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!65 to 74 years'),
#  ('B17001G_015M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!65 to 74 years'),
#  ('B17001G_016E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Male:!!75 years and over'),
#  ('B17001G_016M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Male:!!75 years and over'),
#  ('B17001G_017E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:'),
#  ('B17001G_017M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:'),
#  ('B17001G_018E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!Under 5 years'),
#  ('B17001G_018M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!Under 5 years'),
#  ('B17001G_019E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!5 years'),
#  ('B17001G_019M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!5 years'),
#  ('B17001G_020E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!6 to 11 years'),
#  ('B17001G_020M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!6 to 11 years'),
#  ('B17001G_021E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!12 to 14 years'),
#  ('B17001G_021M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!12 to 14 years'),
#  ('B17001G_022E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!15 years'),
#  ('B17001G_022M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!15 years'),
#  ('B17001G_023E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!16 and 17 years'),
#  ('B17001G_023M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!16 and 17 years'),
#  ('B17001G_024E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!18 to 24 years'),
#  ('B17001G_024M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!18 to 24 years'),
#  ('B17001G_025E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!25 to 34 years'),
#  ('B17001G_025M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!25 to 34 years'),
#  ('B17001G_026E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!35 to 44 years'),
#  ('B17001G_026M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!35 to 44 years'),
#  ('B17001G_027E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!45 to 54 years'),
#  ('B17001G_027M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!45 to 54 years'),
#  ('B17001G_028E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!55 to 64 years'),
#  ('B17001G_028M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!55 to 64 years'),
#  ('B17001G_029E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!65 to 74 years'),
#  ('B17001G_029M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!65 to 74 years'),
#  ('B17001G_030E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months below poverty level:!!Female:!!75 years and over'),
#  ('B17001G_030M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months below poverty level:!!Female:!!75 years and over'),
#  ('B17001G_031E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months at or above poverty level:'),
#  ('B17001G_031M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:'),
#  ('B17001G_032E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months at or above poverty level:!!Male:'),
#  ('B17001G_032M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Male:'),
#  ('B17001G_033E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months at or above poverty level:!!Male:!!Under 5 years'),
#  ('B17001G_033M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Male:!!Under 5 years'),
#  ('B17001G_034E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months at or above poverty level:!!Male:!!5 years'),
#  ('B17001G_034M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Male:!!5 years'),
#  ('B17001G_035E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months at or above poverty level:!!Male:!!6 to 11 years'),
#  ('B17001G_035M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Male:!!6 to 11 years'),
#  ('B17001G_036E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months at or above poverty level:!!Male:!!12 to 14 years'),
#  ('B17001G_036M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Male:!!12 to 14 years'),
#  ('B17001G_037E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months at or above poverty level:!!Male:!!15 years'),
#  ('B17001G_037M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Male:!!15 years'),
#  ('B17001G_038E',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Income in the past 12 months at or above poverty level:!!Male:!!16 and 17 years'),
#  ('B17001G_038M',
#   'B17001G.  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'Margin Of Error For!!Income in the past 12 months at or above poverty level:!!Male:!!16 and 17 years'),
#  ...]

# %%
censusdata.printtable(censusdata.censustable('acs5', 2015, 'B02001'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B02001_001E  | B02001.  Race                  | Total:                                                   | int
# B02001_002E  | B02001.  Race                  | White alone                                              | int
# B02001_003E  | B02001.  Race                  | Black or African American alone                          | int
# B02001_004E  | B02001.  Race                  | American Indian and Alaska Native alone                  | int
# B02001_005E  | B02001.  Race                  | Asian alone                                              | int
# B02001_006E  | B02001.  Race                  | Native Hawaiian and Other Pacific Islander alone         | int
# B02001_007E  | B02001.  Race                  | Some other race alone                                    | int
# B02001_008E  | B02001.  Race                  | Two or more races:                                       | int
# B02001_009E  | B02001.  Race                  | !! Two or more races: Two races including Some other rac | int
# B02001_010E  | B02001.  Race                  | !! Two or more races: Two races excluding Some other rac | int
# -------------------------------------------------------------------------------------------------------------------

# %%
censusdata.geographies(censusdata.censusgeo([('state', '*')]), 'acs5', 2015)
# Out:
# {'Alabama': censusgeo((('state', '01'),)),
#  'Alaska': censusgeo((('state', '02'),)),
#  'Arizona': censusgeo((('state', '04'),)),
#  'Arkansas': censusgeo((('state', '05'),)),
#  'California': censusgeo((('state', '06'),)),
#  'Colorado': censusgeo((('state', '08'),)),
#  'Connecticut': censusgeo((('state', '09'),)),
#  'Delaware': censusgeo((('state', '10'),)),
#  'District of Columbia': censusgeo((('state', '11'),)),
#  'Florida': censusgeo((('state', '12'),)),
#  'Georgia': censusgeo((('state', '13'),)),
#  'Hawaii': censusgeo((('state', '15'),)),
#  'Idaho': censusgeo((('state', '16'),)),
#  'Illinois': censusgeo((('state', '17'),)),
#  'Indiana': censusgeo((('state', '18'),)),
#  'Iowa': censusgeo((('state', '19'),)),
#  'Kansas': censusgeo((('state', '20'),)),
#  'Kentucky': censusgeo((('state', '21'),)),
#  'Louisiana': censusgeo((('state', '22'),)),
#  'Maine': censusgeo((('state', '23'),)),
#  'Maryland': censusgeo((('state', '24'),)),
#  'Massachusetts': censusgeo((('state', '25'),)),
#  'Michigan': censusgeo((('state', '26'),)),
#  'Minnesota': censusgeo((('state', '27'),)),
#  'Mississippi': censusgeo((('state', '28'),)),
#  'Missouri': censusgeo((('state', '29'),)),
#  'Montana': censusgeo((('state', '30'),)),
#  'Nebraska': censusgeo((('state', '31'),)),
#  'Nevada': censusgeo((('state', '32'),)),
#  'New Hampshire': censusgeo((('state', '33'),)),
#  'New Jersey': censusgeo((('state', '34'),)),
#  'New Mexico': censusgeo((('state', '35'),)),
#  'New York': censusgeo((('state', '36'),)),
#  'North Carolina': censusgeo((('state', '37'),)),
#  'North Dakota': censusgeo((('state', '38'),)),
#  'Ohio': censusgeo((('state', '39'),)),
#  'Oklahoma': censusgeo((('state', '40'),)),
#  'Oregon': censusgeo((('state', '41'),)),
#  'Pennsylvania': censusgeo((('state', '42'),)),
#  'Rhode Island': censusgeo((('state', '44'),)),
#  'South Carolina': censusgeo((('state', '45'),)),
#  'South Dakota': censusgeo((('state', '46'),)),
#  'Tennessee': censusgeo((('state', '47'),)),
#  'Texas': censusgeo((('state', '48'),)),
#  'Utah': censusgeo((('state', '49'),)),
#  'Vermont': censusgeo((('state', '50'),)),
#  'Virginia': censusgeo((('state', '51'),)),
#  'Washington': censusgeo((('state', '53'),)),
#  'West Virginia': censusgeo((('state', '54'),)),
#  'Wisconsin': censusgeo((('state', '55'),)),
#  'Wyoming': censusgeo((('state', '56'),)),
#  'Puerto Rico': censusgeo((('state', '72'),))}

# %%
censusdata.geographies(censusdata.censusgeo([('state', '22'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Acadia Parish, Louisiana': censusgeo((('state', '22'), ('county', '001'))),
#  'Allen Parish, Louisiana': censusgeo((('state', '22'), ('county', '003'))),
#  'Ascension Parish, Louisiana': censusgeo((('state', '22'), ('county', '005'))),
#  'Assumption Parish, Louisiana': censusgeo((('state', '22'), ('county', '007'))),
#  'Avoyelles Parish, Louisiana': censusgeo((('state', '22'), ('county', '009'))),
#  'Beauregard Parish, Louisiana': censusgeo((('state', '22'), ('county', '011'))),
#  'Bienville Parish, Louisiana': censusgeo((('state', '22'), ('county', '013'))),
#  'Bossier Parish, Louisiana': censusgeo((('state', '22'), ('county', '015'))),
#  'Caddo Parish, Louisiana': censusgeo((('state', '22'), ('county', '017'))),
#  'Calcasieu Parish, Louisiana': censusgeo((('state', '22'), ('county', '019'))),
#  'Caldwell Parish, Louisiana': censusgeo((('state', '22'), ('county', '021'))),
#  'Cameron Parish, Louisiana': censusgeo((('state', '22'), ('county', '023'))),
#  'Catahoula Parish, Louisiana': censusgeo((('state', '22'), ('county', '025'))),
#  'Claiborne Parish, Louisiana': censusgeo((('state', '22'), ('county', '027'))),
#  'Concordia Parish, Louisiana': censusgeo((('state', '22'), ('county', '029'))),
#  'De Soto Parish, Louisiana': censusgeo((('state', '22'), ('county', '031'))),
#  'East Baton Rouge Parish, Louisiana': censusgeo((('state', '22'), ('county', '033'))),
#  'East Carroll Parish, Louisiana': censusgeo((('state', '22'), ('county', '035'))),
#  'East Feliciana Parish, Louisiana': censusgeo((('state', '22'), ('county', '037'))),
#  'Evangeline Parish, Louisiana': censusgeo((('state', '22'), ('county', '039'))),
#  'Franklin Parish, Louisiana': censusgeo((('state', '22'), ('county', '041'))),
#  'Grant Parish, Louisiana': censusgeo((('state', '22'), ('county', '043'))),
#  'Iberia Parish, Louisiana': censusgeo((('state', '22'), ('county', '045'))),
#  'Iberville Parish, Louisiana': censusgeo((('state', '22'), ('county', '047'))),
#  'Jackson Parish, Louisiana': censusgeo((('state', '22'), ('county', '049'))),
#  'Jefferson Parish, Louisiana': censusgeo((('state', '22'), ('county', '051'))),
#  'Jefferson Davis Parish, Louisiana': censusgeo((('state', '22'), ('county', '053'))),
#  'Lafayette Parish, Louisiana': censusgeo((('state', '22'), ('county', '055'))),
#  'Lafourche Parish, Louisiana': censusgeo((('state', '22'), ('county', '057'))),
#  'LaSalle Parish, Louisiana': censusgeo((('state', '22'), ('county', '059'))),
#  'Lincoln Parish, Louisiana': censusgeo((('state', '22'), ('county', '061'))),
#  'Livingston Parish, Louisiana': censusgeo((('state', '22'), ('county', '063'))),
#  'Madison Parish, Louisiana': censusgeo((('state', '22'), ('county', '065'))),
#  'Morehouse Parish, Louisiana': censusgeo((('state', '22'), ('county', '067'))),
#  'Natchitoches Parish, Louisiana': censusgeo((('state', '22'), ('county', '069'))),
#  'Orleans Parish, Louisiana': censusgeo((('state', '22'), ('county', '071'))),
#  'Ouachita Parish, Louisiana': censusgeo((('state', '22'), ('county', '073'))),
#  'Plaquemines Parish, Louisiana': censusgeo((('state', '22'), ('county', '075'))),
#  'Pointe Coupee Parish, Louisiana': censusgeo((('state', '22'), ('county', '077'))),
#  'Rapides Parish, Louisiana': censusgeo((('state', '22'), ('county', '079'))),
#  'Red River Parish, Louisiana': censusgeo((('state', '22'), ('county', '081'))),
#  'Richland Parish, Louisiana': censusgeo((('state', '22'), ('county', '083'))),
#  'Sabine Parish, Louisiana': censusgeo((('state', '22'), ('county', '085'))),
#  'St. Bernard Parish, Louisiana': censusgeo((('state', '22'), ('county', '087'))),
#  'St. Charles Parish, Louisiana': censusgeo((('state', '22'), ('county', '089'))),
#  'St. Helena Parish, Louisiana': censusgeo((('state', '22'), ('county', '091'))),
#  'St. James Parish, Louisiana': censusgeo((('state', '22'), ('county', '093'))),
#  'St. John the Baptist Parish, Louisiana': censusgeo((('state', '22'), ('county', '095'))),
#  'St. Landry Parish, Louisiana': censusgeo((('state', '22'), ('county', '097'))),
#  'St. Martin Parish, Louisiana': censusgeo((('state', '22'), ('county', '099'))),
#  'St. Mary Parish, Louisiana': censusgeo((('state', '22'), ('county', '101'))),
#  'St. Tammany Parish, Louisiana': censusgeo((('state', '22'), ('county', '103'))),
#  'Tangipahoa Parish, Louisiana': censusgeo((('state', '22'), ('county', '105'))),
#  'Tensas Parish, Louisiana': censusgeo((('state', '22'), ('county', '107'))),
#  'Terrebonne Parish, Louisiana': censusgeo((('state', '22'), ('county', '109'))),
#  'Union Parish, Louisiana': censusgeo((('state', '22'), ('county', '111'))),
#  'Vermilion Parish, Louisiana': censusgeo((('state', '22'), ('county', '113'))),
#  'Vernon Parish, Louisiana': censusgeo((('state', '22'), ('county', '115'))),
#  'Washington Parish, Louisiana': censusgeo((('state', '22'), ('county', '117'))),
#  'Webster Parish, Louisiana': censusgeo((('state', '22'), ('county', '119'))),
#  'West Baton Rouge Parish, Louisiana': censusgeo((('state', '22'), ('county', '121'))),
#  'West Carroll Parish, Louisiana': censusgeo((('state', '22'), ('county', '123'))),
#  'West Feliciana Parish, Louisiana': censusgeo((('state', '22'), ('county', '125'))),
#  'Winn Parish, Louisiana': censusgeo((('state', '22'), ('county', '127')))}

# %%
orleans_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '22'), ('county', '071')]),
                             ['B02001_003E', 'B02001_001E'])

# %%
orleans_data.head()
# Out:
#                                                     B02001_003E  B02001_001E
# Orleans Parish, Louisiana: Summary level: 050, ...       224306       376738

# %%
orleans_data['percent_black'] = orleans_data.B02001_003E / orleans_data.B02001_001E * 100

# %%
orleans_data['Total']= orleans_data.B02001_001E

# %%
orleans_data=orleans_data[['percent_black', 'Total']]

# %%
orleans_data.head()
# Out:
#                                                     percent_black   Total
# Orleans Parish, Louisiana: Summary level: 050, ...       59.53899  376738

# %%
censusdata.geographies(censusdata.censusgeo([('state', '01'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Bibb County, Alabama': censusgeo((('state', '01'), ('county', '007'))),
#  'Blount County, Alabama': censusgeo((('state', '01'), ('county', '009'))),
#  'Bullock County, Alabama': censusgeo((('state', '01'), ('county', '011'))),
#  'Butler County, Alabama': censusgeo((('state', '01'), ('county', '013'))),
#  'Calhoun County, Alabama': censusgeo((('state', '01'), ('county', '015'))),
#  'Chambers County, Alabama': censusgeo((('state', '01'), ('county', '017'))),
#  'Cherokee County, Alabama': censusgeo((('state', '01'), ('county', '019'))),
#  'Chilton County, Alabama': censusgeo((('state', '01'), ('county', '021'))),
#  'Choctaw County, Alabama': censusgeo((('state', '01'), ('county', '023'))),
#  'Clarke County, Alabama': censusgeo((('state', '01'), ('county', '025'))),
#  'Clay County, Alabama': censusgeo((('state', '01'), ('county', '027'))),
#  'Cleburne County, Alabama': censusgeo((('state', '01'), ('county', '029'))),
#  'Coffee County, Alabama': censusgeo((('state', '01'), ('county', '031'))),
#  'Colbert County, Alabama': censusgeo((('state', '01'), ('county', '033'))),
#  'Conecuh County, Alabama': censusgeo((('state', '01'), ('county', '035'))),
#  'Coosa County, Alabama': censusgeo((('state', '01'), ('county', '037'))),
#  'Covington County, Alabama': censusgeo((('state', '01'), ('county', '039'))),
#  'Crenshaw County, Alabama': censusgeo((('state', '01'), ('county', '041'))),
#  'Cullman County, Alabama': censusgeo((('state', '01'), ('county', '043'))),
#  'Dale County, Alabama': censusgeo((('state', '01'), ('county', '045'))),
#  'Dallas County, Alabama': censusgeo((('state', '01'), ('county', '047'))),
#  'DeKalb County, Alabama': censusgeo((('state', '01'), ('county', '049'))),
#  'Elmore County, Alabama': censusgeo((('state', '01'), ('county', '051'))),
#  'Escambia County, Alabama': censusgeo((('state', '01'), ('county', '053'))),
#  'Etowah County, Alabama': censusgeo((('state', '01'), ('county', '055'))),
#  'Fayette County, Alabama': censusgeo((('state', '01'), ('county', '057'))),
#  'Franklin County, Alabama': censusgeo((('state', '01'), ('county', '059'))),
#  'Geneva County, Alabama': censusgeo((('state', '01'), ('county', '061'))),
#  'Greene County, Alabama': censusgeo((('state', '01'), ('county', '063'))),
#  'Hale County, Alabama': censusgeo((('state', '01'), ('county', '065'))),
#  'Henry County, Alabama': censusgeo((('state', '01'), ('county', '067'))),
#  'Houston County, Alabama': censusgeo((('state', '01'), ('county', '069'))),
#  'Jackson County, Alabama': censusgeo((('state', '01'), ('county', '071'))),
#  'Jefferson County, Alabama': censusgeo((('state', '01'), ('county', '073'))),
#  'Lamar County, Alabama': censusgeo((('state', '01'), ('county', '075'))),
#  'Lauderdale County, Alabama': censusgeo((('state', '01'), ('county', '077'))),
#  'Lawrence County, Alabama': censusgeo((('state', '01'), ('county', '079'))),
#  'Lee County, Alabama': censusgeo((('state', '01'), ('county', '081'))),
#  'Limestone County, Alabama': censusgeo((('state', '01'), ('county', '083'))),
#  'Lowndes County, Alabama': censusgeo((('state', '01'), ('county', '085'))),
#  'Macon County, Alabama': censusgeo((('state', '01'), ('county', '087'))),
#  'Madison County, Alabama': censusgeo((('state', '01'), ('county', '089'))),
#  'Marengo County, Alabama': censusgeo((('state', '01'), ('county', '091'))),
#  'Marion County, Alabama': censusgeo((('state', '01'), ('county', '093'))),
#  'Marshall County, Alabama': censusgeo((('state', '01'), ('county', '095'))),
#  'Mobile County, Alabama': censusgeo((('state', '01'), ('county', '097'))),
#  'Monroe County, Alabama': censusgeo((('state', '01'), ('county', '099'))),
#  'Montgomery County, Alabama': censusgeo((('state', '01'), ('county', '101'))),
#  'Morgan County, Alabama': censusgeo((('state', '01'), ('county', '103'))),
#  'Perry County, Alabama': censusgeo((('state', '01'), ('county', '105'))),
#  'Pickens County, Alabama': censusgeo((('state', '01'), ('county', '107'))),
#  'Pike County, Alabama': censusgeo((('state', '01'), ('county', '109'))),
#  'Randolph County, Alabama': censusgeo((('state', '01'), ('county', '111'))),
#  'Russell County, Alabama': censusgeo((('state', '01'), ('county', '113'))),
#  'St. Clair County, Alabama': censusgeo((('state', '01'), ('county', '115'))),
#  'Shelby County, Alabama': censusgeo((('state', '01'), ('county', '117'))),
#  'Sumter County, Alabama': censusgeo((('state', '01'), ('county', '119'))),
#  'Talladega County, Alabama': censusgeo((('state', '01'), ('county', '121'))),
#  'Tallapoosa County, Alabama': censusgeo((('state', '01'), ('county', '123'))),
#  'Tuscaloosa County, Alabama': censusgeo((('state', '01'), ('county', '125'))),
#  'Walker County, Alabama': censusgeo((('state', '01'), ('county', '127'))),
#  'Washington County, Alabama': censusgeo((('state', '01'), ('county', '129'))),
#  'Wilcox County, Alabama': censusgeo((('state', '01'), ('county', '131'))),
#  'Winston County, Alabama': censusgeo((('state', '01'), ('county', '133'))),
#  'Autauga County, Alabama': censusgeo((('state', '01'), ('county', '001'))),
#  'Baldwin County, Alabama': censusgeo((('state', '01'), ('county', '003'))),
#  'Barbour County, Alabama': censusgeo((('state', '01'), ('county', '005')))}

# %%
greene_Al_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '01'), ('county', '063')]),
                             ['B02001_003E', 'B02001_001E'])
tryy2 = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '01'), ('county', '063')]),
                             ['B01003'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /Users/gabriellecatania/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/censusdata/download.py in _download(src, year, params, baseurl, endpt)
#      33         try:
# ---> 34                 data = r.json()
#      35         except:
#
# /Users/gabriellecatania/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#
# /Users/gabriellecatania/opt/anaconda3/envs/PythonData/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#
# /Users/gabriellecatania/opt/anaconda3/envs/PythonData/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#
# /Users/gabriellecatania/opt/anaconda3/envs/PythonData/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-2049188dae95> in <module>()
#       4 tryy2 = censusdata.download('acs5', 2015,
#       5                              censusdata.censusgeo([('state', '01'), ('county', '063')]),
# ----> 6                              ['B01003'])
#
# /Users/gabriellecatania/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/censusdata/download.py in download(src, year, geo, var, key, tabletype, endpt)
#     112                 params.update(georequest)
#     113                 if key is not None: params.update({'key': key})
# --> 114                 data.update(_download(src + tabletype, year, params, endpt=endpt))
#     115         geodata = data.copy()
#     116         for key in list(geodata.keys()):
#
# /Users/gabriellecatania/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/censusdata/download.py in _download(src, year, params, baseurl, endpt)
#      34                 data = r.json()
#      35         except:
# ---> 36                 raise ValueError('Unexpected response (URL: {0.url}): {0.text} '.format(r))
#      37         rdata = OrderedDict()
#      38         for j in range(len(data[0])):
#
# ValueError: Unexpected response (URL: https://api.census.gov/data/2015/acs/acs5?get=NAME,B01003&for=county:063&in=state:01): error: error: unknown variable 'B01003'

# %%
greene_Al_data['percent_black'] = greene_Al_data.B02001_003E / greene_Al_data.B02001_001E * 100
greene_Al_data['Total']= greene_Al_data.B02001_001E
greene_Al_data=greene_Al_data[['percent_black', 'Total']]
greene_Al_data.head()
# Out:
#                                                     percent_black  Total
# Greene County, Alabama: Summary level: 050, sta...      80.659998   8697

# %%
#get list of county codes for all counties in Arkansas
censusdata.geographies(censusdata.censusgeo([('state', '05'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Arkansas County, Arkansas': censusgeo((('state', '05'), ('county', '001'))),
#  'Ashley County, Arkansas': censusgeo((('state', '05'), ('county', '003'))),
#  'Baxter County, Arkansas': censusgeo((('state', '05'), ('county', '005'))),
#  'Benton County, Arkansas': censusgeo((('state', '05'), ('county', '007'))),
#  'Boone County, Arkansas': censusgeo((('state', '05'), ('county', '009'))),
#  'Bradley County, Arkansas': censusgeo((('state', '05'), ('county', '011'))),
#  'Calhoun County, Arkansas': censusgeo((('state', '05'), ('county', '013'))),
#  'Carroll County, Arkansas': censusgeo((('state', '05'), ('county', '015'))),
#  'Chicot County, Arkansas': censusgeo((('state', '05'), ('county', '017'))),
#  'Clark County, Arkansas': censusgeo((('state', '05'), ('county', '019'))),
#  'Clay County, Arkansas': censusgeo((('state', '05'), ('county', '021'))),
#  'Cleburne County, Arkansas': censusgeo((('state', '05'), ('county', '023'))),
#  'Cleveland County, Arkansas': censusgeo((('state', '05'), ('county', '025'))),
#  'Columbia County, Arkansas': censusgeo((('state', '05'), ('county', '027'))),
#  'Conway County, Arkansas': censusgeo((('state', '05'), ('county', '029'))),
#  'Craighead County, Arkansas': censusgeo((('state', '05'), ('county', '031'))),
#  'Crawford County, Arkansas': censusgeo((('state', '05'), ('county', '033'))),
#  'Crittenden County, Arkansas': censusgeo((('state', '05'), ('county', '035'))),
#  'Cross County, Arkansas': censusgeo((('state', '05'), ('county', '037'))),
#  'Dallas County, Arkansas': censusgeo((('state', '05'), ('county', '039'))),
#  'Desha County, Arkansas': censusgeo((('state', '05'), ('county', '041'))),
#  'Drew County, Arkansas': censusgeo((('state', '05'), ('county', '043'))),
#  'Faulkner County, Arkansas': censusgeo((('state', '05'), ('county', '045'))),
#  'Franklin County, Arkansas': censusgeo((('state', '05'), ('county', '047'))),
#  'Fulton County, Arkansas': censusgeo((('state', '05'), ('county', '049'))),
#  'Garland County, Arkansas': censusgeo((('state', '05'), ('county', '051'))),
#  'Grant County, Arkansas': censusgeo((('state', '05'), ('county', '053'))),
#  'Greene County, Arkansas': censusgeo((('state', '05'), ('county', '055'))),
#  'Hempstead County, Arkansas': censusgeo((('state', '05'), ('county', '057'))),
#  'Hot Spring County, Arkansas': censusgeo((('state', '05'), ('county', '059'))),
#  'Howard County, Arkansas': censusgeo((('state', '05'), ('county', '061'))),
#  'Independence County, Arkansas': censusgeo((('state', '05'), ('county', '063'))),
#  'Izard County, Arkansas': censusgeo((('state', '05'), ('county', '065'))),
#  'Jackson County, Arkansas': censusgeo((('state', '05'), ('county', '067'))),
#  'Jefferson County, Arkansas': censusgeo((('state', '05'), ('county', '069'))),
#  'Johnson County, Arkansas': censusgeo((('state', '05'), ('county', '071'))),
#  'Lafayette County, Arkansas': censusgeo((('state', '05'), ('county', '073'))),
#  'Lawrence County, Arkansas': censusgeo((('state', '05'), ('county', '075'))),
#  'Lee County, Arkansas': censusgeo((('state', '05'), ('county', '077'))),
#  'Lincoln County, Arkansas': censusgeo((('state', '05'), ('county', '079'))),
#  'Little River County, Arkansas': censusgeo((('state', '05'), ('county', '081'))),
#  'Logan County, Arkansas': censusgeo((('state', '05'), ('county', '083'))),
#  'Lonoke County, Arkansas': censusgeo((('state', '05'), ('county', '085'))),
#  'Madison County, Arkansas': censusgeo((('state', '05'), ('county', '087'))),
#  'Marion County, Arkansas': censusgeo((('state', '05'), ('county', '089'))),
#  'Miller County, Arkansas': censusgeo((('state', '05'), ('county', '091'))),
#  'Mississippi County, Arkansas': censusgeo((('state', '05'), ('county', '093'))),
#  'Monroe County, Arkansas': censusgeo((('state', '05'), ('county', '095'))),
#  'Montgomery County, Arkansas': censusgeo((('state', '05'), ('county', '097'))),
#  'Nevada County, Arkansas': censusgeo((('state', '05'), ('county', '099'))),
#  'Newton County, Arkansas': censusgeo((('state', '05'), ('county', '101'))),
#  'Ouachita County, Arkansas': censusgeo((('state', '05'), ('county', '103'))),
#  'Perry County, Arkansas': censusgeo((('state', '05'), ('county', '105'))),
#  'Phillips County, Arkansas': censusgeo((('state', '05'), ('county', '107'))),
#  'Pike County, Arkansas': censusgeo((('state', '05'), ('county', '109'))),
#  'Poinsett County, Arkansas': censusgeo((('state', '05'), ('county', '111'))),
#  'Polk County, Arkansas': censusgeo((('state', '05'), ('county', '113'))),
#  'Pope County, Arkansas': censusgeo((('state', '05'), ('county', '115'))),
#  'Prairie County, Arkansas': censusgeo((('state', '05'), ('county', '117'))),
#  'Pulaski County, Arkansas': censusgeo((('state', '05'), ('county', '119'))),
#  'Randolph County, Arkansas': censusgeo((('state', '05'), ('county', '121'))),
#  'St. Francis County, Arkansas': censusgeo((('state', '05'), ('county', '123'))),
#  'Saline County, Arkansas': censusgeo((('state', '05'), ('county', '125'))),
#  'Scott County, Arkansas': censusgeo((('state', '05'), ('county', '127'))),
#  'Searcy County, Arkansas': censusgeo((('state', '05'), ('county', '129'))),
#  'Sebastian County, Arkansas': censusgeo((('state', '05'), ('county', '131'))),
#  'Sevier County, Arkansas': censusgeo((('state', '05'), ('county', '133'))),
#  'Sharp County, Arkansas': censusgeo((('state', '05'), ('county', '135'))),
#  'Stone County, Arkansas': censusgeo((('state', '05'), ('county', '137'))),
#  'Union County, Arkansas': censusgeo((('state', '05'), ('county', '139'))),
#  'Van Buren County, Arkansas': censusgeo((('state', '05'), ('county', '141'))),
#  'Washington County, Arkansas': censusgeo((('state', '05'), ('county', '143'))),
#  'White County, Arkansas': censusgeo((('state', '05'), ('county', '145'))),
#  'Woodruff County, Arkansas': censusgeo((('state', '05'), ('county', '147'))),
#  'Yell County, Arkansas': censusgeo((('state', '05'), ('county', '149')))}

# %%
phillipsAK_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '05'), ('county', '107')]),
                             ['B02001_003E', 'B02001_001E'])

# %%
phillipsAK_data['percent_black'] = phillipsAK_data.B02001_003E / phillipsAK_data.B02001_001E * 100
phillipsAK_data['Total']= phillipsAK_data.B02001_001E
phillipsAK_data=phillipsAK_data[['percent_black', 'Total']]
phillipsAK_data.head()
# Out:
#                                                     percent_black  Total
# Phillips County, Arkansas: Summary level: 050, ...       61.52224  20391

# %%
#get list of county codes for all counties in Georgia
censusdata.geographies(censusdata.censusgeo([('state', '13'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Appling County, Georgia': censusgeo((('state', '13'), ('county', '001'))),
#  'Atkinson County, Georgia': censusgeo((('state', '13'), ('county', '003'))),
#  'Bacon County, Georgia': censusgeo((('state', '13'), ('county', '005'))),
#  'Baker County, Georgia': censusgeo((('state', '13'), ('county', '007'))),
#  'Baldwin County, Georgia': censusgeo((('state', '13'), ('county', '009'))),
#  'Banks County, Georgia': censusgeo((('state', '13'), ('county', '011'))),
#  'Barrow County, Georgia': censusgeo((('state', '13'), ('county', '013'))),
#  'Bartow County, Georgia': censusgeo((('state', '13'), ('county', '015'))),
#  'Ben Hill County, Georgia': censusgeo((('state', '13'), ('county', '017'))),
#  'Berrien County, Georgia': censusgeo((('state', '13'), ('county', '019'))),
#  'Bibb County, Georgia': censusgeo((('state', '13'), ('county', '021'))),
#  'Bleckley County, Georgia': censusgeo((('state', '13'), ('county', '023'))),
#  'Brantley County, Georgia': censusgeo((('state', '13'), ('county', '025'))),
#  'Brooks County, Georgia': censusgeo((('state', '13'), ('county', '027'))),
#  'Bryan County, Georgia': censusgeo((('state', '13'), ('county', '029'))),
#  'Bulloch County, Georgia': censusgeo((('state', '13'), ('county', '031'))),
#  'Burke County, Georgia': censusgeo((('state', '13'), ('county', '033'))),
#  'Butts County, Georgia': censusgeo((('state', '13'), ('county', '035'))),
#  'Calhoun County, Georgia': censusgeo((('state', '13'), ('county', '037'))),
#  'Camden County, Georgia': censusgeo((('state', '13'), ('county', '039'))),
#  'Candler County, Georgia': censusgeo((('state', '13'), ('county', '043'))),
#  'Carroll County, Georgia': censusgeo((('state', '13'), ('county', '045'))),
#  'Catoosa County, Georgia': censusgeo((('state', '13'), ('county', '047'))),
#  'Charlton County, Georgia': censusgeo((('state', '13'), ('county', '049'))),
#  'Chatham County, Georgia': censusgeo((('state', '13'), ('county', '051'))),
#  'Chattahoochee County, Georgia': censusgeo((('state', '13'), ('county', '053'))),
#  'Chattooga County, Georgia': censusgeo((('state', '13'), ('county', '055'))),
#  'Cherokee County, Georgia': censusgeo((('state', '13'), ('county', '057'))),
#  'Clarke County, Georgia': censusgeo((('state', '13'), ('county', '059'))),
#  'Clay County, Georgia': censusgeo((('state', '13'), ('county', '061'))),
#  'Clayton County, Georgia': censusgeo((('state', '13'), ('county', '063'))),
#  'Clinch County, Georgia': censusgeo((('state', '13'), ('county', '065'))),
#  'Cobb County, Georgia': censusgeo((('state', '13'), ('county', '067'))),
#  'Coffee County, Georgia': censusgeo((('state', '13'), ('county', '069'))),
#  'Colquitt County, Georgia': censusgeo((('state', '13'), ('county', '071'))),
#  'Columbia County, Georgia': censusgeo((('state', '13'), ('county', '073'))),
#  'Cook County, Georgia': censusgeo((('state', '13'), ('county', '075'))),
#  'Coweta County, Georgia': censusgeo((('state', '13'), ('county', '077'))),
#  'Crawford County, Georgia': censusgeo((('state', '13'), ('county', '079'))),
#  'Crisp County, Georgia': censusgeo((('state', '13'), ('county', '081'))),
#  'Dade County, Georgia': censusgeo((('state', '13'), ('county', '083'))),
#  'Dawson County, Georgia': censusgeo((('state', '13'), ('county', '085'))),
#  'Decatur County, Georgia': censusgeo((('state', '13'), ('county', '087'))),
#  'DeKalb County, Georgia': censusgeo((('state', '13'), ('county', '089'))),
#  'Dodge County, Georgia': censusgeo((('state', '13'), ('county', '091'))),
#  'Dooly County, Georgia': censusgeo((('state', '13'), ('county', '093'))),
#  'Dougherty County, Georgia': censusgeo((('state', '13'), ('county', '095'))),
#  'Douglas County, Georgia': censusgeo((('state', '13'), ('county', '097'))),
#  'Early County, Georgia': censusgeo((('state', '13'), ('county', '099'))),
#  'Echols County, Georgia': censusgeo((('state', '13'), ('county', '101'))),
#  'Effingham County, Georgia': censusgeo((('state', '13'), ('county', '103'))),
#  'Elbert County, Georgia': censusgeo((('state', '13'), ('county', '105'))),
#  'Emanuel County, Georgia': censusgeo((('state', '13'), ('county', '107'))),
#  'Evans County, Georgia': censusgeo((('state', '13'), ('county', '109'))),
#  'Fannin County, Georgia': censusgeo((('state', '13'), ('county', '111'))),
#  'Fayette County, Georgia': censusgeo((('state', '13'), ('county', '113'))),
#  'Floyd County, Georgia': censusgeo((('state', '13'), ('county', '115'))),
#  'Forsyth County, Georgia': censusgeo((('state', '13'), ('county', '117'))),
#  'Franklin County, Georgia': censusgeo((('state', '13'), ('county', '119'))),
#  'Fulton County, Georgia': censusgeo((('state', '13'), ('county', '121'))),
#  'Gilmer County, Georgia': censusgeo((('state', '13'), ('county', '123'))),
#  'Glascock County, Georgia': censusgeo((('state', '13'), ('county', '125'))),
#  'Glynn County, Georgia': censusgeo((('state', '13'), ('county', '127'))),
#  'Gordon County, Georgia': censusgeo((('state', '13'), ('county', '129'))),
#  'Grady County, Georgia': censusgeo((('state', '13'), ('county', '131'))),
#  'Greene County, Georgia': censusgeo((('state', '13'), ('county', '133'))),
#  'Gwinnett County, Georgia': censusgeo((('state', '13'), ('county', '135'))),
#  'Habersham County, Georgia': censusgeo((('state', '13'), ('county', '137'))),
#  'Hall County, Georgia': censusgeo((('state', '13'), ('county', '139'))),
#  'Hancock County, Georgia': censusgeo((('state', '13'), ('county', '141'))),
#  'Haralson County, Georgia': censusgeo((('state', '13'), ('county', '143'))),
#  'Harris County, Georgia': censusgeo((('state', '13'), ('county', '145'))),
#  'Hart County, Georgia': censusgeo((('state', '13'), ('county', '147'))),
#  'Heard County, Georgia': censusgeo((('state', '13'), ('county', '149'))),
#  'Henry County, Georgia': censusgeo((('state', '13'), ('county', '151'))),
#  'Houston County, Georgia': censusgeo((('state', '13'), ('county', '153'))),
#  'Irwin County, Georgia': censusgeo((('state', '13'), ('county', '155'))),
#  'Jackson County, Georgia': censusgeo((('state', '13'), ('county', '157'))),
#  'Jasper County, Georgia': censusgeo((('state', '13'), ('county', '159'))),
#  'Jeff Davis County, Georgia': censusgeo((('state', '13'), ('county', '161'))),
#  'Jefferson County, Georgia': censusgeo((('state', '13'), ('county', '163'))),
#  'Jenkins County, Georgia': censusgeo((('state', '13'), ('county', '165'))),
#  'Johnson County, Georgia': censusgeo((('state', '13'), ('county', '167'))),
#  'Jones County, Georgia': censusgeo((('state', '13'), ('county', '169'))),
#  'Lamar County, Georgia': censusgeo((('state', '13'), ('county', '171'))),
#  'Lanier County, Georgia': censusgeo((('state', '13'), ('county', '173'))),
#  'Laurens County, Georgia': censusgeo((('state', '13'), ('county', '175'))),
#  'Lee County, Georgia': censusgeo((('state', '13'), ('county', '177'))),
#  'Liberty County, Georgia': censusgeo((('state', '13'), ('county', '179'))),
#  'Lincoln County, Georgia': censusgeo((('state', '13'), ('county', '181'))),
#  'Long County, Georgia': censusgeo((('state', '13'), ('county', '183'))),
#  'Lowndes County, Georgia': censusgeo((('state', '13'), ('county', '185'))),
#  'Lumpkin County, Georgia': censusgeo((('state', '13'), ('county', '187'))),
#  'McDuffie County, Georgia': censusgeo((('state', '13'), ('county', '189'))),
#  'McIntosh County, Georgia': censusgeo((('state', '13'), ('county', '191'))),
#  'Macon County, Georgia': censusgeo((('state', '13'), ('county', '193'))),
#  'Madison County, Georgia': censusgeo((('state', '13'), ('county', '195'))),
#  'Marion County, Georgia': censusgeo((('state', '13'), ('county', '197'))),
#  'Meriwether County, Georgia': censusgeo((('state', '13'), ('county', '199'))),
#  'Miller County, Georgia': censusgeo((('state', '13'), ('county', '201'))),
#  'Mitchell County, Georgia': censusgeo((('state', '13'), ('county', '205'))),
#  'Monroe County, Georgia': censusgeo((('state', '13'), ('county', '207'))),
#  'Montgomery County, Georgia': censusgeo((('state', '13'), ('county', '209'))),
#  'Morgan County, Georgia': censusgeo((('state', '13'), ('county', '211'))),
#  'Murray County, Georgia': censusgeo((('state', '13'), ('county', '213'))),
#  'Muscogee County, Georgia': censusgeo((('state', '13'), ('county', '215'))),
#  'Newton County, Georgia': censusgeo((('state', '13'), ('county', '217'))),
#  'Oconee County, Georgia': censusgeo((('state', '13'), ('county', '219'))),
#  'Oglethorpe County, Georgia': censusgeo((('state', '13'), ('county', '221'))),
#  'Paulding County, Georgia': censusgeo((('state', '13'), ('county', '223'))),
#  'Peach County, Georgia': censusgeo((('state', '13'), ('county', '225'))),
#  'Pickens County, Georgia': censusgeo((('state', '13'), ('county', '227'))),
#  'Pierce County, Georgia': censusgeo((('state', '13'), ('county', '229'))),
#  'Pike County, Georgia': censusgeo((('state', '13'), ('county', '231'))),
#  'Polk County, Georgia': censusgeo((('state', '13'), ('county', '233'))),
#  'Pulaski County, Georgia': censusgeo((('state', '13'), ('county', '235'))),
#  'Putnam County, Georgia': censusgeo((('state', '13'), ('county', '237'))),
#  'Quitman County, Georgia': censusgeo((('state', '13'), ('county', '239'))),
#  'Rabun County, Georgia': censusgeo((('state', '13'), ('county', '241'))),
#  'Randolph County, Georgia': censusgeo((('state', '13'), ('county', '243'))),
#  'Richmond County, Georgia': censusgeo((('state', '13'), ('county', '245'))),
#  'Rockdale County, Georgia': censusgeo((('state', '13'), ('county', '247'))),
#  'Schley County, Georgia': censusgeo((('state', '13'), ('county', '249'))),
#  'Screven County, Georgia': censusgeo((('state', '13'), ('county', '251'))),
#  'Seminole County, Georgia': censusgeo((('state', '13'), ('county', '253'))),
#  'Spalding County, Georgia': censusgeo((('state', '13'), ('county', '255'))),
#  'Stephens County, Georgia': censusgeo((('state', '13'), ('county', '257'))),
#  'Stewart County, Georgia': censusgeo((('state', '13'), ('county', '259'))),
#  'Sumter County, Georgia': censusgeo((('state', '13'), ('county', '261'))),
#  'Talbot County, Georgia': censusgeo((('state', '13'), ('county', '263'))),
#  'Taliaferro County, Georgia': censusgeo((('state', '13'), ('county', '265'))),
#  'Tattnall County, Georgia': censusgeo((('state', '13'), ('county', '267'))),
#  'Taylor County, Georgia': censusgeo((('state', '13'), ('county', '269'))),
#  'Telfair County, Georgia': censusgeo((('state', '13'), ('county', '271'))),
#  'Terrell County, Georgia': censusgeo((('state', '13'), ('county', '273'))),
#  'Thomas County, Georgia': censusgeo((('state', '13'), ('county', '275'))),
#  'Tift County, Georgia': censusgeo((('state', '13'), ('county', '277'))),
#  'Toombs County, Georgia': censusgeo((('state', '13'), ('county', '279'))),
#  'Towns County, Georgia': censusgeo((('state', '13'), ('county', '281'))),
#  'Treutlen County, Georgia': censusgeo((('state', '13'), ('county', '283'))),
#  'Troup County, Georgia': censusgeo((('state', '13'), ('county', '285'))),
#  'Turner County, Georgia': censusgeo((('state', '13'), ('county', '287'))),
#  'Twiggs County, Georgia': censusgeo((('state', '13'), ('county', '289'))),
#  'Union County, Georgia': censusgeo((('state', '13'), ('county', '291'))),
#  'Upson County, Georgia': censusgeo((('state', '13'), ('county', '293'))),
#  'Walker County, Georgia': censusgeo((('state', '13'), ('county', '295'))),
#  'Walton County, Georgia': censusgeo((('state', '13'), ('county', '297'))),
#  'Ware County, Georgia': censusgeo((('state', '13'), ('county', '299'))),
#  'Warren County, Georgia': censusgeo((('state', '13'), ('county', '301'))),
#  'Washington County, Georgia': censusgeo((('state', '13'), ('county', '303'))),
#  'Wayne County, Georgia': censusgeo((('state', '13'), ('county', '305'))),
#  'Webster County, Georgia': censusgeo((('state', '13'), ('county', '307'))),
#  'Wheeler County, Georgia': censusgeo((('state', '13'), ('county', '309'))),
#  'White County, Georgia': censusgeo((('state', '13'), ('county', '311'))),
#  'Whitfield County, Georgia': censusgeo((('state', '13'), ('county', '313'))),
#  'Wilcox County, Georgia': censusgeo((('state', '13'), ('county', '315'))),
#  'Wilkes County, Georgia': censusgeo((('state', '13'), ('county', '317'))),
#  'Wilkinson County, Georgia': censusgeo((('state', '13'), ('county', '319'))),
#  'Worth County, Georgia': censusgeo((('state', '13'), ('county', '321')))}

# %%
hancockGA_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '13'), ('county', '141')]),
                             ['B02001_003E', 'B02001_001E'])

# %%
hancockGA_data['percent_black'] = hancockGA_data.B02001_003E / hancockGA_data.B02001_001E * 100
hancockGA_data['Total']= hancockGA_data.B02001_001E
hancockGA_data=hancockGA_data[['percent_black', 'Total']]
hancockGA_data.head()
# Out:
#                                                     percent_black  Total
# Hancock County, Georgia: Summary level: 050, st...      73.223736   8881

# %%
cities = censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '13'), ('county', '141')]), ['B01001_001E'])

# %%
cities
# Out:
#                                                     B01001_001E
# Hancock County, Georgia: Summary level: 050, st...         8881

# %%
key = key_dict['census']
c = Census(key,year = 2015)
greene_Al_data2 = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '01'), ('county', '063')]),
                             ['B02001_003E'])

# %%
cities2 = censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '13'), ('county', '141')]), ['B02001_003E'])

# %%
cities2 = cities2.append(greene_Al_data2)

# %%
orleans = censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '22'), ('county', '071')]), ['B02001_003E'])

# %%
phillips = censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '05'), ('county', '107')]), ['B02001_003E'])

# %%
cities2 = cities2.append(orleans)

# %%
cities2=cities2.append(phillips)

# %%
cities2
# Out:
#                                                     B02001_003E
# Hancock County, Georgia: Summary level: 050, st...         6503
# Greene County, Alabama: Summary level: 050, sta...         7015
# Orleans Parish, Louisiana: Summary level: 050, ...       224306
# Phillips County, Arkansas: Summary level: 050, ...        12545

# %%
#get list of county codes for all counties in MI
censusdata.geographies(censusdata.censusgeo([('state', '28'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Adams County, Mississippi': censusgeo((('state', '28'), ('county', '001'))),
#  'Alcorn County, Mississippi': censusgeo((('state', '28'), ('county', '003'))),
#  'Amite County, Mississippi': censusgeo((('state', '28'), ('county', '005'))),
#  'Attala County, Mississippi': censusgeo((('state', '28'), ('county', '007'))),
#  'Benton County, Mississippi': censusgeo((('state', '28'), ('county', '009'))),
#  'Bolivar County, Mississippi': censusgeo((('state', '28'), ('county', '011'))),
#  'Calhoun County, Mississippi': censusgeo((('state', '28'), ('county', '013'))),
#  'Carroll County, Mississippi': censusgeo((('state', '28'), ('county', '015'))),
#  'Chickasaw County, Mississippi': censusgeo((('state', '28'), ('county', '017'))),
#  'Choctaw County, Mississippi': censusgeo((('state', '28'), ('county', '019'))),
#  'Claiborne County, Mississippi': censusgeo((('state', '28'), ('county', '021'))),
#  'Clarke County, Mississippi': censusgeo((('state', '28'), ('county', '023'))),
#  'Clay County, Mississippi': censusgeo((('state', '28'), ('county', '025'))),
#  'Coahoma County, Mississippi': censusgeo((('state', '28'), ('county', '027'))),
#  'Copiah County, Mississippi': censusgeo((('state', '28'), ('county', '029'))),
#  'Covington County, Mississippi': censusgeo((('state', '28'), ('county', '031'))),
#  'DeSoto County, Mississippi': censusgeo((('state', '28'), ('county', '033'))),
#  'Forrest County, Mississippi': censusgeo((('state', '28'), ('county', '035'))),
#  'Franklin County, Mississippi': censusgeo((('state', '28'), ('county', '037'))),
#  'George County, Mississippi': censusgeo((('state', '28'), ('county', '039'))),
#  'Greene County, Mississippi': censusgeo((('state', '28'), ('county', '041'))),
#  'Grenada County, Mississippi': censusgeo((('state', '28'), ('county', '043'))),
#  'Hancock County, Mississippi': censusgeo((('state', '28'), ('county', '045'))),
#  'Harrison County, Mississippi': censusgeo((('state', '28'), ('county', '047'))),
#  'Hinds County, Mississippi': censusgeo((('state', '28'), ('county', '049'))),
#  'Holmes County, Mississippi': censusgeo((('state', '28'), ('county', '051'))),
#  'Humphreys County, Mississippi': censusgeo((('state', '28'), ('county', '053'))),
#  'Issaquena County, Mississippi': censusgeo((('state', '28'), ('county', '055'))),
#  'Itawamba County, Mississippi': censusgeo((('state', '28'), ('county', '057'))),
#  'Jackson County, Mississippi': censusgeo((('state', '28'), ('county', '059'))),
#  'Jasper County, Mississippi': censusgeo((('state', '28'), ('county', '061'))),
#  'Jefferson County, Mississippi': censusgeo((('state', '28'), ('county', '063'))),
#  'Jefferson Davis County, Mississippi': censusgeo((('state', '28'), ('county', '065'))),
#  'Jones County, Mississippi': censusgeo((('state', '28'), ('county', '067'))),
#  'Kemper County, Mississippi': censusgeo((('state', '28'), ('county', '069'))),
#  'Lafayette County, Mississippi': censusgeo((('state', '28'), ('county', '071'))),
#  'Lamar County, Mississippi': censusgeo((('state', '28'), ('county', '073'))),
#  'Lauderdale County, Mississippi': censusgeo((('state', '28'), ('county', '075'))),
#  'Lawrence County, Mississippi': censusgeo((('state', '28'), ('county', '077'))),
#  'Leake County, Mississippi': censusgeo((('state', '28'), ('county', '079'))),
#  'Lee County, Mississippi': censusgeo((('state', '28'), ('county', '081'))),
#  'Leflore County, Mississippi': censusgeo((('state', '28'), ('county', '083'))),
#  'Lincoln County, Mississippi': censusgeo((('state', '28'), ('county', '085'))),
#  'Lowndes County, Mississippi': censusgeo((('state', '28'), ('county', '087'))),
#  'Madison County, Mississippi': censusgeo((('state', '28'), ('county', '089'))),
#  'Marion County, Mississippi': censusgeo((('state', '28'), ('county', '091'))),
#  'Marshall County, Mississippi': censusgeo((('state', '28'), ('county', '093'))),
#  'Monroe County, Mississippi': censusgeo((('state', '28'), ('county', '095'))),
#  'Montgomery County, Mississippi': censusgeo((('state', '28'), ('county', '097'))),
#  'Neshoba County, Mississippi': censusgeo((('state', '28'), ('county', '099'))),
#  'Newton County, Mississippi': censusgeo((('state', '28'), ('county', '101'))),
#  'Noxubee County, Mississippi': censusgeo((('state', '28'), ('county', '103'))),
#  'Oktibbeha County, Mississippi': censusgeo((('state', '28'), ('county', '105'))),
#  'Panola County, Mississippi': censusgeo((('state', '28'), ('county', '107'))),
#  'Pearl River County, Mississippi': censusgeo((('state', '28'), ('county', '109'))),
#  'Perry County, Mississippi': censusgeo((('state', '28'), ('county', '111'))),
#  'Pike County, Mississippi': censusgeo((('state', '28'), ('county', '113'))),
#  'Pontotoc County, Mississippi': censusgeo((('state', '28'), ('county', '115'))),
#  'Prentiss County, Mississippi': censusgeo((('state', '28'), ('county', '117'))),
#  'Quitman County, Mississippi': censusgeo((('state', '28'), ('county', '119'))),
#  'Rankin County, Mississippi': censusgeo((('state', '28'), ('county', '121'))),
#  'Scott County, Mississippi': censusgeo((('state', '28'), ('county', '123'))),
#  'Sharkey County, Mississippi': censusgeo((('state', '28'), ('county', '125'))),
#  'Simpson County, Mississippi': censusgeo((('state', '28'), ('county', '127'))),
#  'Smith County, Mississippi': censusgeo((('state', '28'), ('county', '129'))),
#  'Stone County, Mississippi': censusgeo((('state', '28'), ('county', '131'))),
#  'Sunflower County, Mississippi': censusgeo((('state', '28'), ('county', '133'))),
#  'Tallahatchie County, Mississippi': censusgeo((('state', '28'), ('county', '135'))),
#  'Tate County, Mississippi': censusgeo((('state', '28'), ('county', '137'))),
#  'Tippah County, Mississippi': censusgeo((('state', '28'), ('county', '139'))),
#  'Tishomingo County, Mississippi': censusgeo((('state', '28'), ('county', '141'))),
#  'Tunica County, Mississippi': censusgeo((('state', '28'), ('county', '143'))),
#  'Union County, Mississippi': censusgeo((('state', '28'), ('county', '145'))),
#  'Walthall County, Mississippi': censusgeo((('state', '28'), ('county', '147'))),
#  'Warren County, Mississippi': censusgeo((('state', '28'), ('county', '149'))),
#  'Washington County, Mississippi': censusgeo((('state', '28'), ('county', '151'))),
#  'Wayne County, Mississippi': censusgeo((('state', '28'), ('county', '153'))),
#  'Webster County, Mississippi': censusgeo((('state', '28'), ('county', '155'))),
#  'Wilkinson County, Mississippi': censusgeo((('state', '28'), ('county', '157'))),
#  'Winston County, Mississippi': censusgeo((('state', '28'), ('county', '159'))),
#  'Yalobusha County, Mississippi': censusgeo((('state', '28'), ('county', '161'))),
#  'Yazoo County, Mississippi': censusgeo((('state', '28'), ('county', '163')))}

# %%
jeffersonMI_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '28'), ('county', '063')]),
                             ['B02001_003E', 'B02001_001E'])

# %%
jeffersonMI_data['percent_black'] = jeffersonMI_data.B02001_003E / jeffersonMI_data.B02001_001E * 100
jeffersonMI_data['Total']= jeffersonMI_data.B02001_001E
jeffersonMI_data=jeffersonMI_data[['percent_black', 'Total']]
jeffersonMI_data.head()
# Out:
#                                                     percent_black  Total
# Jefferson County, Mississippi: Summary level: 0...      85.947799   7586

# %%
jefferson = censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '28'), ('county', '063')]), ['B02001_003E'])

# %%
cities2 = cities2.append(jefferson)

# %%
cities2
# Out:
#                                                     B02001_003E
# Hancock County, Georgia: Summary level: 050, st...         6503
# Greene County, Alabama: Summary level: 050, sta...         7015
# Orleans Parish, Louisiana: Summary level: 050, ...       224306
# Phillips County, Arkansas: Summary level: 050, ...        12545
# Jefferson County, Mississippi: Summary level: 0...         6520

# %%
censusdata.printtable(censusdata.censustable('acs5', 2015, 'B03002'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B03002_001E  | B03002.  Hispanic or Latino by | Total:                                                   | int
# B03002_002E  | B03002.  Hispanic or Latino by | Not Hispanic or Latino:                                  | int
# B03002_003E  | B03002.  Hispanic or Latino by | !! Not Hispanic or Latino: White alone                   | int
# B03002_004E  | B03002.  Hispanic or Latino by | !! Not Hispanic or Latino: Black or African American alo | int
# B03002_005E  | B03002.  Hispanic or Latino by | !! Not Hispanic or Latino: American Indian and Alaska Na | int
# B03002_006E  | B03002.  Hispanic or Latino by | !! Not Hispanic or Latino: Asian alone                   | int
# B03002_007E  | B03002.  Hispanic or Latino by | !! Not Hispanic or Latino: Native Hawaiian and Other Pac | int
# B03002_008E  | B03002.  Hispanic or Latino by | !! Not Hispanic or Latino: Some other race alone         | int
# B03002_009E  | B03002.  Hispanic or Latino by | !! Not Hispanic or Latino: Two or more races:            | int
# B03002_010E  | B03002.  Hispanic or Latino by | !! !! Not Hispanic or Latino: Two or more races: Two rac | int
# B03002_011E  | B03002.  Hispanic or Latino by | !! !! Not Hispanic or Latino: Two or more races: Two rac | int
# B03002_012E  | B03002.  Hispanic or Latino by | Hispanic or Latino:                                      | int
# B03002_013E  | B03002.  Hispanic or Latino by | !! Hispanic or Latino: White alone                       | int
# B03002_014E  | B03002.  Hispanic or Latino by | !! Hispanic or Latino: Black or African American alone   | int
# B03002_015E  | B03002.  Hispanic or Latino by | !! Hispanic or Latino: American Indian and Alaska Native | int
# B03002_016E  | B03002.  Hispanic or Latino by | !! Hispanic or Latino: Asian alone                       | int
# B03002_017E  | B03002.  Hispanic or Latino by | !! Hispanic or Latino: Native Hawaiian and Other Pacific | int
# B03002_018E  | B03002.  Hispanic or Latino by | !! Hispanic or Latino: Some other race alone             | int
# B03002_019E  | B03002.  Hispanic or Latino by | !! Hispanic or Latino: Two or more races:                | int
# B03002_020E  | B03002.  Hispanic or Latino by | !! !! Hispanic or Latino: Two or more races: Two races i | int
# B03002_021E  | B03002.  Hispanic or Latino by | !! !! Hispanic or Latino: Two or more races: Two races e | int
# -------------------------------------------------------------------------------------------------------------------

# %%
censusdata.search('acs5', 2015, 'concept', 'POPULATION')
# Out:
# [('B00001_001E',
#   'B00001.  Unweighted Sample Count of the Population',
#   'Total'),
#  ('B00001_001M',
#   'B00001.  Unweighted Sample Count of the Population',
#   'Margin Of Error For!!Total'),
#  ('B01003_001E', 'B01003.  Total Population', 'Total'),
#  ('B01003_001M', 'B01003.  Total Population', 'Margin Of Error For!!Total'),
#  ('B05006PR_001E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Total:'),
#  ('B05006PR_001M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Total:'),
#  ('B05006PR_002E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Europe:'),
#  ('B05006PR_002M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Europe:'),
#  ('B05006PR_003E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Europe:!!Northern Europe'),
#  ('B05006PR_003M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Europe:!!Northern Europe'),
#  ('B05006PR_004E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Europe:!!Western Europe'),
#  ('B05006PR_004M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Europe:!!Western Europe'),
#  ('B05006PR_005E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Europe:!!Southern Europe:'),
#  ('B05006PR_005M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Europe:!!Southern Europe:'),
#  ('B05006PR_006E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Europe:!!Southern Europe:!!Spain'),
#  ('B05006PR_006M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Europe:!!Southern Europe:!!Spain'),
#  ('B05006PR_007E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Europe:!!Southern Europe:!!Other Southern Europe'),
#  ('B05006PR_007M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Europe:!!Southern Europe:!!Other Southern Europe'),
#  ('B05006PR_008E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Europe:!!Eastern Europe'),
#  ('B05006PR_008M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Europe:!!Eastern Europe'),
#  ('B05006PR_009E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Europe:!!Europe, n.e.c.'),
#  ('B05006PR_009M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Europe:!!Europe, n.e.c.'),
#  ('B05006PR_010E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:'),
#  ('B05006PR_010M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:'),
#  ('B05006PR_011E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!Eastern Asia:'),
#  ('B05006PR_011M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!Eastern Asia:'),
#  ('B05006PR_012E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!Eastern Asia:!!China:'),
#  ('B05006PR_012M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!Eastern Asia:!!China:'),
#  ('B05006PR_013E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!Eastern Asia:!!China:!!China, excluding Taiwan'),
#  ('B05006PR_013M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!Eastern Asia:!!China:!!China, excluding Taiwan'),
#  ('B05006PR_014E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!Eastern Asia:!!China:!!Taiwan'),
#  ('B05006PR_014M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!Eastern Asia:!!China:!!Taiwan'),
#  ('B05006PR_015E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!Eastern Asia:!!Korea'),
#  ('B05006PR_015M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!Eastern Asia:!!Korea'),
#  ('B05006PR_016E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!Eastern Asia:!!Other Eastern Asia'),
#  ('B05006PR_016M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!Eastern Asia:!!Other Eastern Asia'),
#  ('B05006PR_017E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!South Central Asia'),
#  ('B05006PR_017M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!South Central Asia'),
#  ('B05006PR_018E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!South Eastern Asia'),
#  ('B05006PR_018M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!South Eastern Asia'),
#  ('B05006PR_019E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!Western Asia'),
#  ('B05006PR_019M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!Western Asia'),
#  ('B05006PR_020E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Asia:!!Asia,n.e.c.'),
#  ('B05006PR_020M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Asia:!!Asia,n.e.c.'),
#  ('B05006PR_021E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Africa'),
#  ('B05006PR_021M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Africa'),
#  ('B05006PR_022E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Oceania'),
#  ('B05006PR_022M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Oceania'),
#  ('B05006PR_023E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:'),
#  ('B05006PR_023M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:'),
#  ('B05006PR_024E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:'),
#  ('B05006PR_024M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:'),
#  ('B05006PR_025E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Caribbean:'),
#  ('B05006PR_025M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Caribbean:'),
#  ('B05006PR_026E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Caribbean:!!Cuba'),
#  ('B05006PR_026M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Caribbean:!!Cuba'),
#  ('B05006PR_027E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Caribbean:!!Dominican Republic'),
#  ('B05006PR_027M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Caribbean:!!Dominican Republic'),
#  ('B05006PR_028E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Caribbean:!!Haiti'),
#  ('B05006PR_028M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Caribbean:!!Haiti'),
#  ('B05006PR_029E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Caribbean:!!Other Caribbean'),
#  ('B05006PR_029M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Caribbean:!!Other Caribbean'),
#  ('B05006PR_030E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Central America:'),
#  ('B05006PR_030M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Central America:'),
#  ('B05006PR_031E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Central America:!!Mexico'),
#  ('B05006PR_031M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Central America:!!Mexico'),
#  ('B05006PR_032E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Central America:!!Costa Rica'),
#  ('B05006PR_032M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Central America:!!Costa Rica'),
#  ('B05006PR_033E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Central America:!!El Salvador'),
#  ('B05006PR_033M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Central America:!!El Salvador'),
#  ('B05006PR_034E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Central America:!!Guatemala'),
#  ('B05006PR_034M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Central America:!!Guatemala'),
#  ('B05006PR_035E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Central America:!!Honduras'),
#  ('B05006PR_035M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Central America:!!Honduras'),
#  ('B05006PR_036E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Central America:!!Panama'),
#  ('B05006PR_036M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Central America:!!Panama'),
#  ('B05006PR_037E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!Central America:!!Other Central America'),
#  ('B05006PR_037M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!Central America:!!Other Central America'),
#  ('B05006PR_038E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!South America:'),
#  ('B05006PR_038M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!South America:'),
#  ('B05006PR_039E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!South America:!!Argentina'),
#  ('B05006PR_039M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!South America:!!Argentina'),
#  ('B05006PR_040E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!South America:!!Chile'),
#  ('B05006PR_040M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!South America:!!Chile'),
#  ('B05006PR_041E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!South America:!!Colombia'),
#  ('B05006PR_041M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!South America:!!Colombia'),
#  ('B05006PR_042E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!South America:!!Ecuador'),
#  ('B05006PR_042M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!South America:!!Ecuador'),
#  ('B05006PR_043E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!South America:!!Peru'),
#  ('B05006PR_043M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!South America:!!Peru'),
#  ('B05006PR_044E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!South America:!!Venezuela'),
#  ('B05006PR_044M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!South America:!!Venezuela'),
#  ('B05006PR_045E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Latin America:!!South America:!!Other South America'),
#  ('B05006PR_045M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Latin America:!!South America:!!Other South America'),
#  ('B05006PR_046E',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Americas:!!Northern America'),
#  ('B05006PR_046M',
#   'B05006PR.  Place of Birth for the Foreign-Born Population in Puerto Rico',
#   'Margin Of Error For!!Americas:!!Northern America'),
#  ('B05006_001E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Total:'),
#  ('B05006_001M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Total:'),
#  ('B05006_002E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:'),
#  ('B05006_002M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:'),
#  ('B05006_003E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:'),
#  ('B05006_003M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:'),
#  ('B05006_004E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!United Kingdom (inc. Crown Dependencies):'),
#  ('B05006_004M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!United Kingdom (inc. Crown Dependencies):'),
#  ('B05006_005E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!United Kingdom (inc. Crown Dependencies):!!United Kingdom, excluding England and Scotland'),
#  ('B05006_005M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!United Kingdom (inc. Crown Dependencies):!!United Kingdom, excluding England and Scotland'),
#  ('B05006_006E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!United Kingdom (inc. Crown Dependencies):!!England'),
#  ('B05006_006M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!United Kingdom (inc. Crown Dependencies):!!England'),
#  ('B05006_007E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!United Kingdom (inc. Crown Dependencies):!!Scotland'),
#  ('B05006_007M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!United Kingdom (inc. Crown Dependencies):!!Scotland'),
#  ('B05006_008E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!Ireland'),
#  ('B05006_008M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!Ireland'),
#  ('B05006_009E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!Denmark'),
#  ('B05006_009M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!Denmark'),
#  ('B05006_010E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!Norway'),
#  ('B05006_010M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!Norway'),
#  ('B05006_011E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!Sweden'),
#  ('B05006_011M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!Sweden'),
#  ('B05006_012E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Northern Europe:!!Other Northern Europe'),
#  ('B05006_012M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Northern Europe:!!Other Northern Europe'),
#  ('B05006_013E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Western Europe:'),
#  ('B05006_013M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Western Europe:'),
#  ('B05006_014E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Western Europe:!!Austria'),
#  ('B05006_014M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Western Europe:!!Austria'),
#  ('B05006_015E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Western Europe:!!Belgium'),
#  ('B05006_015M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Western Europe:!!Belgium'),
#  ('B05006_016E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Western Europe:!!France'),
#  ('B05006_016M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Western Europe:!!France'),
#  ('B05006_017E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Western Europe:!!Germany'),
#  ('B05006_017M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Western Europe:!!Germany'),
#  ('B05006_018E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Western Europe:!!Netherlands'),
#  ('B05006_018M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Western Europe:!!Netherlands'),
#  ('B05006_019E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Western Europe:!!Switzerland'),
#  ('B05006_019M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Western Europe:!!Switzerland'),
#  ('B05006_020E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Western Europe:!!Other Western Europe'),
#  ('B05006_020M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Western Europe:!!Other Western Europe'),
#  ('B05006_021E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Southern Europe:'),
#  ('B05006_021M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Southern Europe:'),
#  ('B05006_022E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Southern Europe:!!Greece'),
#  ('B05006_022M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Southern Europe:!!Greece'),
#  ('B05006_023E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Southern Europe:!!Italy'),
#  ('B05006_023M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Southern Europe:!!Italy'),
#  ('B05006_024E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Southern Europe:!!Portugal'),
#  ('B05006_024M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Southern Europe:!!Portugal'),
#  ('B05006_025E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Southern Europe:!!Portugal!!Azores Islands'),
#  ('B05006_025M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Southern Europe:!!Portugal!!Azores Islands'),
#  ('B05006_026E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Southern Europe:!!Spain'),
#  ('B05006_026M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Southern Europe:!!Spain'),
#  ('B05006_027E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Southern Europe:!!Other Southern Europe'),
#  ('B05006_027M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Southern Europe:!!Other Southern Europe'),
#  ('B05006_028E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:'),
#  ('B05006_028M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:'),
#  ('B05006_029E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Albania'),
#  ('B05006_029M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Albania'),
#  ('B05006_030E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Belarus'),
#  ('B05006_030M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Belarus'),
#  ('B05006_031E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Bulgaria'),
#  ('B05006_031M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Bulgaria'),
#  ('B05006_032E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Croatia'),
#  ('B05006_032M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Croatia'),
#  ('B05006_033E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Czechoslovakia (includes Czech Republic and Slovakia)'),
#  ('B05006_033M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Czechoslovakia (includes Czech Republic and Slovakia)'),
#  ('B05006_034E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Hungary'),
#  ('B05006_034M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Hungary'),
#  ('B05006_035E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Latvia'),
#  ('B05006_035M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Latvia'),
#  ('B05006_036E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Lithuania'),
#  ('B05006_036M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Lithuania'),
#  ('B05006_037E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Macedonia'),
#  ('B05006_037M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Macedonia'),
#  ('B05006_038E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Moldova'),
#  ('B05006_038M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Moldova'),
#  ('B05006_039E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Poland'),
#  ('B05006_039M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Poland'),
#  ('B05006_040E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Romania'),
#  ('B05006_040M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Romania'),
#  ('B05006_041E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Russia'),
#  ('B05006_041M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Russia'),
#  ('B05006_042E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Ukraine'),
#  ('B05006_042M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Ukraine'),
#  ('B05006_043E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Bosnia and Herzegovina'),
#  ('B05006_043M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Bosnia and Herzegovina'),
#  ('B05006_044E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Serbia'),
#  ('B05006_044M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Serbia'),
#  ('B05006_045E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Eastern Europe:!!Other Eastern Europe'),
#  ('B05006_045M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Eastern Europe:!!Other Eastern Europe'),
#  ('B05006_046E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Europe:!!Europe, n.e.c.'),
#  ('B05006_046M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Europe:!!Europe, n.e.c.'),
#  ('B05006_047E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:'),
#  ('B05006_047M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:'),
#  ('B05006_048E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Eastern Asia:'),
#  ('B05006_048M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Eastern Asia:'),
#  ('B05006_049E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Eastern Asia:!!China:'),
#  ('B05006_049M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Eastern Asia:!!China:'),
#  ('B05006_050E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Eastern Asia:!!China:!!China, excluding Hong Kong and Taiwan'),
#  ('B05006_050M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Eastern Asia:!!China:!!China, excluding Hong Kong and Taiwan'),
#  ('B05006_051E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Eastern Asia:!!China:!!Hong Kong'),
#  ('B05006_051M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Eastern Asia:!!China:!!Hong Kong'),
#  ('B05006_052E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Eastern Asia:!!China:!!Taiwan'),
#  ('B05006_052M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Eastern Asia:!!China:!!Taiwan'),
#  ('B05006_053E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Eastern Asia:!!Japan'),
#  ('B05006_053M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Eastern Asia:!!Japan'),
#  ('B05006_054E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Eastern Asia:!!Korea'),
#  ('B05006_054M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Eastern Asia:!!Korea'),
#  ('B05006_055E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Eastern Asia:!!Other Eastern Asia'),
#  ('B05006_055M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Eastern Asia:!!Other Eastern Asia'),
#  ('B05006_056E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:'),
#  ('B05006_056M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:'),
#  ('B05006_057E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Afghanistan'),
#  ('B05006_057M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Afghanistan'),
#  ('B05006_058E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Bangladesh'),
#  ('B05006_058M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Bangladesh'),
#  ('B05006_059E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!India'),
#  ('B05006_059M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!India'),
#  ('B05006_060E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Iran'),
#  ('B05006_060M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Iran'),
#  ('B05006_061E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Kazakhstan'),
#  ('B05006_061M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Kazakhstan'),
#  ('B05006_062E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Nepal'),
#  ('B05006_062M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Nepal'),
#  ('B05006_063E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Pakistan'),
#  ('B05006_063M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Pakistan'),
#  ('B05006_064E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Sri Lanka'),
#  ('B05006_064M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Sri Lanka'),
#  ('B05006_065E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Uzbekistan'),
#  ('B05006_065M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Uzbekistan'),
#  ('B05006_066E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Central Asia:!!Other South Central Asia'),
#  ('B05006_066M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Central Asia:!!Other South Central Asia'),
#  ('B05006_067E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:'),
#  ('B05006_067M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:'),
#  ('B05006_068E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Cambodia'),
#  ('B05006_068M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Cambodia'),
#  ('B05006_069E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Indonesia'),
#  ('B05006_069M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Indonesia'),
#  ('B05006_070E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Laos'),
#  ('B05006_070M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Laos'),
#  ('B05006_071E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Malaysia'),
#  ('B05006_071M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Malaysia'),
#  ('B05006_072E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Burma'),
#  ('B05006_072M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Burma'),
#  ('B05006_073E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Philippines'),
#  ('B05006_073M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Philippines'),
#  ('B05006_074E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Singapore'),
#  ('B05006_074M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Singapore'),
#  ('B05006_075E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Thailand'),
#  ('B05006_075M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Thailand'),
#  ('B05006_076E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Vietnam'),
#  ('B05006_076M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Vietnam'),
#  ('B05006_077E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!South Eastern Asia:!!Other South Eastern Asia'),
#  ('B05006_077M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!South Eastern Asia:!!Other South Eastern Asia'),
#  ('B05006_078E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:'),
#  ('B05006_078M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:'),
#  ('B05006_079E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Iraq'),
#  ('B05006_079M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Iraq'),
#  ('B05006_080E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Israel'),
#  ('B05006_080M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Israel'),
#  ('B05006_081E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Jordan'),
#  ('B05006_081M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Jordan'),
#  ('B05006_082E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Kuwait'),
#  ('B05006_082M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Kuwait'),
#  ('B05006_083E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Lebanon'),
#  ('B05006_083M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Lebanon'),
#  ('B05006_084E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Saudi Arabia'),
#  ('B05006_084M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Saudi Arabia'),
#  ('B05006_085E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Syria'),
#  ('B05006_085M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Syria'),
#  ('B05006_086E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Yemen'),
#  ('B05006_086M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Yemen'),
#  ('B05006_087E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Turkey'),
#  ('B05006_087M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Turkey'),
#  ('B05006_088E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Armenia'),
#  ('B05006_088M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Armenia'),
#  ('B05006_089E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Western Asia:!!Other Western Asia'),
#  ('B05006_089M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Western Asia:!!Other Western Asia'),
#  ('B05006_090E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Asia:!!Asia,n.e.c.'),
#  ('B05006_090M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Asia:!!Asia,n.e.c.'),
#  ('B05006_091E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:'),
#  ('B05006_091M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:'),
#  ('B05006_092E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Eastern Africa:'),
#  ('B05006_092M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Eastern Africa:'),
#  ('B05006_093E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Eastern Africa:!!Eritrea'),
#  ('B05006_093M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Eastern Africa:!!Eritrea'),
#  ('B05006_094E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Eastern Africa:!!Ethiopia'),
#  ('B05006_094M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Eastern Africa:!!Ethiopia'),
#  ('B05006_095E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Eastern Africa:!!Kenya'),
#  ('B05006_095M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Eastern Africa:!!Kenya'),
#  ('B05006_096E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Eastern Africa:!!Somalia'),
#  ('B05006_096M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Eastern Africa:!!Somalia'),
#  ('B05006_097E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Eastern Africa:!!Other Eastern Africa'),
#  ('B05006_097M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Eastern Africa:!!Other Eastern Africa'),
#  ('B05006_098E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Middle Africa:'),
#  ('B05006_098M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Middle Africa:'),
#  ('B05006_099E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Middle Africa:!!Cameroon'),
#  ('B05006_099M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Middle Africa:!!Cameroon'),
#  ('B05006_100E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Middle Africa:!!Other Middle Africa'),
#  ('B05006_100M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Middle Africa:!!Other Middle Africa'),
#  ('B05006_101E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Northern Africa:'),
#  ('B05006_101M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Northern Africa:'),
#  ('B05006_102E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Northern Africa:!!Egypt'),
#  ('B05006_102M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Northern Africa:!!Egypt'),
#  ('B05006_103E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Northern Africa:!!Morocco'),
#  ('B05006_103M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Northern Africa:!!Morocco'),
#  ('B05006_104E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Northern Africa:!!Sudan'),
#  ('B05006_104M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Northern Africa:!!Sudan'),
#  ('B05006_105E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Northern Africa:!!Other Northern Africa'),
#  ('B05006_105M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Northern Africa:!!Other Northern Africa'),
#  ('B05006_106E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Southern Africa:'),
#  ('B05006_106M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Southern Africa:'),
#  ('B05006_107E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Southern Africa:!!South Africa'),
#  ('B05006_107M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Southern Africa:!!South Africa'),
#  ('B05006_108E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Southern Africa:!!Other Southern Africa'),
#  ('B05006_108M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Southern Africa:!!Other Southern Africa'),
#  ('B05006_109E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Western Africa:'),
#  ('B05006_109M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Western Africa:'),
#  ('B05006_110E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Western Africa:!!Cabo Verde'),
#  ('B05006_110M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Western Africa:!!Cabo Verde'),
#  ('B05006_111E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Western Africa:!!Ghana'),
#  ('B05006_111M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Western Africa:!!Ghana'),
#  ('B05006_112E',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Africa:!!Western Africa:!!Liberia'),
#  ('B05006_112M',
#   'B05006. Place of Birth for the Foreign-Born Population in the United States',
#   'Margin of Error for!!Africa:!!Western Africa:!!Liberia'),
#  ('B05006_113E',
# ...
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In family households:!!Spouse'),
#  ('B09020_008E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In family households:!!Parent'),
#  ('B09020_008M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In family households:!!Parent'),
#  ('B09020_009E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In family households:!!Parent-in-law'),
#  ('B09020_009M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In family households:!!Parent-in-law'),
#  ('B09020_010E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In family households:!!Other relatives'),
#  ('B09020_010M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In family households:!!Other relatives'),
#  ('B09020_011E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In family households:!!Nonrelatives'),
#  ('B09020_011M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In family households:!!Nonrelatives'),
#  ('B09020_012E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:'),
#  ('B09020_012M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:'),
#  ('B09020_013E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:!!Householder:'),
#  ('B09020_013M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:!!Householder:'),
#  ('B09020_014E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:!!Householder:!!Male:'),
#  ('B09020_014M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:!!Householder:!!Male:'),
#  ('B09020_015E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:!!Householder:!!Male:!!Living alone'),
#  ('B09020_015M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:!!Householder:!!Male:!!Living alone'),
#  ('B09020_016E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:!!Householder:!!Male:!!Not living alone'),
#  ('B09020_016M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:!!Householder:!!Male:!!Not living alone'),
#  ('B09020_017E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:!!Householder:!!Female:'),
#  ('B09020_017M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:!!Householder:!!Female:'),
#  ('B09020_018E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:!!Householder:!!Female:!!Living alone'),
#  ('B09020_018M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:!!Householder:!!Female:!!Living alone'),
#  ('B09020_019E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:!!Householder:!!Female:!!Not living alone'),
#  ('B09020_019M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:!!Householder:!!Female:!!Not living alone'),
#  ('B09020_020E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In households:!!In nonfamily households:!!Nonrelatives'),
#  ('B09020_020M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In households:!!In nonfamily households:!!Nonrelatives'),
#  ('B09020_021E',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'In group quarters'),
#  ('B09020_021M',
#   'B09020.  Relationship by Household Type (Including Living Alone) for the Population 65 Years and Over',
#   'Margin of Error for!!In group quarters'),
#  ('B11002A_001E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Total:'),
#  ('B11002A_001M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!Total:'),
#  ('B11002A_002E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:'),
#  ('B11002A_002M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:'),
#  ('B11002A_003E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In married-couple family:'),
#  ('B11002A_003M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In married-couple family:'),
#  ('B11002A_004E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In married-couple family:!!Relatives'),
#  ('B11002A_004M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In married-couple family:!!Relatives'),
#  ('B11002A_005E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In married-couple family:!!Nonrelatives'),
#  ('B11002A_005M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In married-couple family:!!Nonrelatives'),
#  ('B11002A_006E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In male householder, no wife present, family:'),
#  ('B11002A_006M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In male householder, no wife present, family:'),
#  ('B11002A_007E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In male householder, no wife present, family:!!Relatives'),
#  ('B11002A_007M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In male householder, no wife present, family:!!Relatives'),
#  ('B11002A_008E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In male householder, no wife present, family:!!Nonrelatives'),
#  ('B11002A_008M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In male householder, no wife present, family:!!Nonrelatives'),
#  ('B11002A_009E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In female householder, no husband present, family:'),
#  ('B11002A_009M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In female householder, no husband present, family:'),
#  ('B11002A_010E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In female householder, no husband present, family:!!Relatives'),
#  ('B11002A_010M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In female householder, no husband present, family:!!Relatives'),
#  ('B11002A_011E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In family households:!!In female householder, no husband present, family:!!Nonrelatives'),
#  ('B11002A_011M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In family households:!!In female householder, no husband present, family:!!Nonrelatives'),
#  ('B11002A_012E',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'In nonfamily households'),
#  ('B11002A_012M',
#   'B11002A.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'Margin Of Error For!!In nonfamily households'),
#  ('B11002B_001E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Total:'),
#  ('B11002B_001M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!Total:'),
#  ('B11002B_002E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:'),
#  ('B11002B_002M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:'),
#  ('B11002B_003E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In married-couple family:'),
#  ('B11002B_003M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In married-couple family:'),
#  ('B11002B_004E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In married-couple family:!!Relatives'),
#  ('B11002B_004M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In married-couple family:!!Relatives'),
#  ('B11002B_005E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In married-couple family:!!Nonrelatives'),
#  ('B11002B_005M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In married-couple family:!!Nonrelatives'),
#  ('B11002B_006E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In male householder, no wife present, family:'),
#  ('B11002B_006M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In male householder, no wife present, family:'),
#  ('B11002B_007E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In male householder, no wife present, family:!!Relatives'),
#  ('B11002B_007M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In male householder, no wife present, family:!!Relatives'),
#  ('B11002B_008E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In male householder, no wife present, family:!!Nonrelatives'),
#  ('B11002B_008M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In male householder, no wife present, family:!!Nonrelatives'),
#  ('B11002B_009E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In female householder, no husband present, family:'),
#  ('B11002B_009M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In female householder, no husband present, family:'),
#  ('B11002B_010E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In female householder, no husband present, family:!!Relatives'),
#  ('B11002B_010M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In female householder, no husband present, family:!!Relatives'),
#  ('B11002B_011E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In family households:!!In female householder, no husband present, family:!!Nonrelatives'),
#  ('B11002B_011M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In family households:!!In female householder, no husband present, family:!!Nonrelatives'),
#  ('B11002B_012E',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'In nonfamily households'),
#  ('B11002B_012M',
#   'B11002B.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Margin Of Error For!!In nonfamily households'),
#  ('B11002C_001E',
#   'B11002C.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Total:'),
#  ('B11002C_001M',
#   'B11002C.  HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Margin Of Error For!!Total:'),
#  ...]

# %%
censusdata.printtable(censusdata.censustable('acs5', 2015, 'B01003'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B01003_001E  | B01003.  Total Population      | Total                                                    | int
# -------------------------------------------------------------------------------------------------------------------

# %%
#get list of county codes for all counties in AZ
censusdata.geographies(censusdata.censusgeo([('state', '04'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Apache County, Arizona': censusgeo((('state', '04'), ('county', '001'))),
#  'Cochise County, Arizona': censusgeo((('state', '04'), ('county', '003'))),
#  'Coconino County, Arizona': censusgeo((('state', '04'), ('county', '005'))),
#  'Gila County, Arizona': censusgeo((('state', '04'), ('county', '007'))),
#  'Graham County, Arizona': censusgeo((('state', '04'), ('county', '009'))),
#  'Greenlee County, Arizona': censusgeo((('state', '04'), ('county', '011'))),
#  'La Paz County, Arizona': censusgeo((('state', '04'), ('county', '012'))),
#  'Maricopa County, Arizona': censusgeo((('state', '04'), ('county', '013'))),
#  'Mohave County, Arizona': censusgeo((('state', '04'), ('county', '015'))),
#  'Navajo County, Arizona': censusgeo((('state', '04'), ('county', '017'))),
#  'Pima County, Arizona': censusgeo((('state', '04'), ('county', '019'))),
#  'Pinal County, Arizona': censusgeo((('state', '04'), ('county', '021'))),
#  'Santa Cruz County, Arizona': censusgeo((('state', '04'), ('county', '023'))),
#  'Yavapai County, Arizona': censusgeo((('state', '04'), ('county', '025'))),
#  'Yuma County, Arizona': censusgeo((('state', '04'), ('county', '027')))}

# %%
santacruzAZ_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '04'), ('county', '023')]),
                             ['B03002_012E', 'B01003_001E'])

# %%
santacruzAZ_data
# Out:
#                                                     B03002_012E  B01003_001E
# Santa Cruz County, Arizona: Summary level: 050,...        38965        47073

# %%
santacruzAZ_data['Percent_Hispanic/Latino']= santacruzAZ_data.B03002_012E/santacruzAZ_data.B01003_001E *100

# %%
santacruzAZ_data
# Out:
#                                                     B03002_012E  B01003_001E  \
# Santa Cruz County, Arizona: Summary level: 050,...        38965        47073
#
#                                                     Percent_Hispanic/Latino
# Santa Cruz County, Arizona: Summary level: 050,...                82.775689

# %%
#get list of county codes for all counties in CA
censusdata.geographies(censusdata.censusgeo([('state', '06'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Alameda County, California': censusgeo((('state', '06'), ('county', '001'))),
#  'Alpine County, California': censusgeo((('state', '06'), ('county', '003'))),
#  'Amador County, California': censusgeo((('state', '06'), ('county', '005'))),
#  'Butte County, California': censusgeo((('state', '06'), ('county', '007'))),
#  'Calaveras County, California': censusgeo((('state', '06'), ('county', '009'))),
#  'Colusa County, California': censusgeo((('state', '06'), ('county', '011'))),
#  'Contra Costa County, California': censusgeo((('state', '06'), ('county', '013'))),
#  'Del Norte County, California': censusgeo((('state', '06'), ('county', '015'))),
#  'El Dorado County, California': censusgeo((('state', '06'), ('county', '017'))),
#  'Fresno County, California': censusgeo((('state', '06'), ('county', '019'))),
#  'Glenn County, California': censusgeo((('state', '06'), ('county', '021'))),
#  'Humboldt County, California': censusgeo((('state', '06'), ('county', '023'))),
#  'Imperial County, California': censusgeo((('state', '06'), ('county', '025'))),
#  'Inyo County, California': censusgeo((('state', '06'), ('county', '027'))),
#  'Kern County, California': censusgeo((('state', '06'), ('county', '029'))),
#  'Kings County, California': censusgeo((('state', '06'), ('county', '031'))),
#  'Lake County, California': censusgeo((('state', '06'), ('county', '033'))),
#  'Lassen County, California': censusgeo((('state', '06'), ('county', '035'))),
#  'Los Angeles County, California': censusgeo((('state', '06'), ('county', '037'))),
#  'Madera County, California': censusgeo((('state', '06'), ('county', '039'))),
#  'Marin County, California': censusgeo((('state', '06'), ('county', '041'))),
#  'Mariposa County, California': censusgeo((('state', '06'), ('county', '043'))),
#  'Mendocino County, California': censusgeo((('state', '06'), ('county', '045'))),
#  'Merced County, California': censusgeo((('state', '06'), ('county', '047'))),
#  'Modoc County, California': censusgeo((('state', '06'), ('county', '049'))),
#  'Mono County, California': censusgeo((('state', '06'), ('county', '051'))),
#  'Monterey County, California': censusgeo((('state', '06'), ('county', '053'))),
#  'Napa County, California': censusgeo((('state', '06'), ('county', '055'))),
#  'Nevada County, California': censusgeo((('state', '06'), ('county', '057'))),
#  'Orange County, California': censusgeo((('state', '06'), ('county', '059'))),
#  'Placer County, California': censusgeo((('state', '06'), ('county', '061'))),
#  'Plumas County, California': censusgeo((('state', '06'), ('county', '063'))),
#  'Riverside County, California': censusgeo((('state', '06'), ('county', '065'))),
#  'Sacramento County, California': censusgeo((('state', '06'), ('county', '067'))),
#  'San Benito County, California': censusgeo((('state', '06'), ('county', '069'))),
#  'San Bernardino County, California': censusgeo((('state', '06'), ('county', '071'))),
#  'San Diego County, California': censusgeo((('state', '06'), ('county', '073'))),
#  'San Francisco County, California': censusgeo((('state', '06'), ('county', '075'))),
#  'San Joaquin County, California': censusgeo((('state', '06'), ('county', '077'))),
#  'San Luis Obispo County, California': censusgeo((('state', '06'), ('county', '079'))),
#  'San Mateo County, California': censusgeo((('state', '06'), ('county', '081'))),
#  'Santa Barbara County, California': censusgeo((('state', '06'), ('county', '083'))),
#  'Santa Clara County, California': censusgeo((('state', '06'), ('county', '085'))),
#  'Santa Cruz County, California': censusgeo((('state', '06'), ('county', '087'))),
#  'Shasta County, California': censusgeo((('state', '06'), ('county', '089'))),
#  'Sierra County, California': censusgeo((('state', '06'), ('county', '091'))),
#  'Siskiyou County, California': censusgeo((('state', '06'), ('county', '093'))),
#  'Solano County, California': censusgeo((('state', '06'), ('county', '095'))),
#  'Sonoma County, California': censusgeo((('state', '06'), ('county', '097'))),
#  'Stanislaus County, California': censusgeo((('state', '06'), ('county', '099'))),
#  'Sutter County, California': censusgeo((('state', '06'), ('county', '101'))),
#  'Tehama County, California': censusgeo((('state', '06'), ('county', '103'))),
#  'Trinity County, California': censusgeo((('state', '06'), ('county', '105'))),
#  'Tulare County, California': censusgeo((('state', '06'), ('county', '107'))),
#  'Tuolumne County, California': censusgeo((('state', '06'), ('county', '109'))),
#  'Ventura County, California': censusgeo((('state', '06'), ('county', '111'))),
#  'Yolo County, California': censusgeo((('state', '06'), ('county', '113'))),
#  'Yuba County, California': censusgeo((('state', '06'), ('county', '115')))}

# %%
imperialCA_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '06'), ('county', '025')]),
                             ['B03002_012E', 'B01003_001E'])

# %%
imperialCA_data['Percent_Hispanic/Latino']= imperialCA_data.B03002_012E/imperialCA_data.B01003_001E *100
imperialCA_data.head()
# Out:
#                                                     B03002_012E  B01003_001E  \
# Imperial County, California: Summary level: 050...       145855       178206
#
#                                                     Percent_Hispanic/Latino
# Imperial County, California: Summary level: 050...                 81.84629

# %%
#get list of county codes for all counties in CA
censusdata.geographies(censusdata.censusgeo([('state', '35'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Bernalillo County, New Mexico': censusgeo((('state', '35'), ('county', '001'))),
#  'Catron County, New Mexico': censusgeo((('state', '35'), ('county', '003'))),
#  'Chaves County, New Mexico': censusgeo((('state', '35'), ('county', '005'))),
#  'Cibola County, New Mexico': censusgeo((('state', '35'), ('county', '006'))),
#  'Colfax County, New Mexico': censusgeo((('state', '35'), ('county', '007'))),
#  'Curry County, New Mexico': censusgeo((('state', '35'), ('county', '009'))),
#  'De Baca County, New Mexico': censusgeo((('state', '35'), ('county', '011'))),
#  'Do?a Ana County, New Mexico': censusgeo((('state', '35'), ('county', '013'))),
#  'Eddy County, New Mexico': censusgeo((('state', '35'), ('county', '015'))),
#  'Grant County, New Mexico': censusgeo((('state', '35'), ('county', '017'))),
#  'Guadalupe County, New Mexico': censusgeo((('state', '35'), ('county', '019'))),
#  'Harding County, New Mexico': censusgeo((('state', '35'), ('county', '021'))),
#  'Hidalgo County, New Mexico': censusgeo((('state', '35'), ('county', '023'))),
#  'Lea County, New Mexico': censusgeo((('state', '35'), ('county', '025'))),
#  'Lincoln County, New Mexico': censusgeo((('state', '35'), ('county', '027'))),
#  'Los Alamos County, New Mexico': censusgeo((('state', '35'), ('county', '028'))),
#  'Luna County, New Mexico': censusgeo((('state', '35'), ('county', '029'))),
#  'McKinley County, New Mexico': censusgeo((('state', '35'), ('county', '031'))),
#  'Mora County, New Mexico': censusgeo((('state', '35'), ('county', '033'))),
#  'Otero County, New Mexico': censusgeo((('state', '35'), ('county', '035'))),
#  'Quay County, New Mexico': censusgeo((('state', '35'), ('county', '037'))),
#  'Rio Arriba County, New Mexico': censusgeo((('state', '35'), ('county', '039'))),
#  'Roosevelt County, New Mexico': censusgeo((('state', '35'), ('county', '041'))),
#  'Sandoval County, New Mexico': censusgeo((('state', '35'), ('county', '043'))),
#  'San Juan County, New Mexico': censusgeo((('state', '35'), ('county', '045'))),
#  'San Miguel County, New Mexico': censusgeo((('state', '35'), ('county', '047'))),
#  'Santa Fe County, New Mexico': censusgeo((('state', '35'), ('county', '049'))),
#  'Sierra County, New Mexico': censusgeo((('state', '35'), ('county', '051'))),
#  'Socorro County, New Mexico': censusgeo((('state', '35'), ('county', '053'))),
#  'Taos County, New Mexico': censusgeo((('state', '35'), ('county', '055'))),
#  'Torrance County, New Mexico': censusgeo((('state', '35'), ('county', '057'))),
#  'Union County, New Mexico': censusgeo((('state', '35'), ('county', '059'))),
#  'Valencia County, New Mexico': censusgeo((('state', '35'), ('county', '061')))}

# %%
guadalupeNM_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '35'), ('county', '019')]),
                             ['B03002_012E', 'B01003_001E'])

# %%
guadalupeNM_data['Percent_Hispanic/Latino']= guadalupeNM_data.B03002_012E/guadalupeNM_data.B01003_001E *100
guadalupeNM_data.head()
# Out:
#                                                     B03002_012E  B01003_001E  \
# Guadalupe County, New Mexico: Summary level: 05...         3498         4526
#
#                                                     Percent_Hispanic/Latino
# Guadalupe County, New Mexico: Summary level: 05...                77.286787

# %%
moraNM_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '35'), ('county', '033')]),
                             ['B03002_012E', 'B01003_001E'])

# %%
moraNM_data['Percent_Hispanic/Latino']= moraNM_data.B03002_012E/moraNM_data.B01003_001E *100
moraNM_data.head()
# Out:
#                                                     B03002_012E  B01003_001E  \
# Mora County, New Mexico: Summary level: 050, st...         3838         4660
#
#                                                     Percent_Hispanic/Latino
# Mora County, New Mexico: Summary level: 050, st...                82.360515

# %%
censusdata.geographies(censusdata.censusgeo([('state', '48'), ('county', '*')]), 'acs5', 2015)
# Out:
# {'Anderson County, Texas': censusgeo((('state', '48'), ('county', '001'))),
#  'Andrews County, Texas': censusgeo((('state', '48'), ('county', '003'))),
#  'Angelina County, Texas': censusgeo((('state', '48'), ('county', '005'))),
#  'Aransas County, Texas': censusgeo((('state', '48'), ('county', '007'))),
#  'Archer County, Texas': censusgeo((('state', '48'), ('county', '009'))),
#  'Armstrong County, Texas': censusgeo((('state', '48'), ('county', '011'))),
#  'Atascosa County, Texas': censusgeo((('state', '48'), ('county', '013'))),
#  'Austin County, Texas': censusgeo((('state', '48'), ('county', '015'))),
#  'Bailey County, Texas': censusgeo((('state', '48'), ('county', '017'))),
#  'Bandera County, Texas': censusgeo((('state', '48'), ('county', '019'))),
#  'Bastrop County, Texas': censusgeo((('state', '48'), ('county', '021'))),
#  'Baylor County, Texas': censusgeo((('state', '48'), ('county', '023'))),
#  'Bee County, Texas': censusgeo((('state', '48'), ('county', '025'))),
#  'Bell County, Texas': censusgeo((('state', '48'), ('county', '027'))),
#  'Bexar County, Texas': censusgeo((('state', '48'), ('county', '029'))),
#  'Blanco County, Texas': censusgeo((('state', '48'), ('county', '031'))),
#  'Borden County, Texas': censusgeo((('state', '48'), ('county', '033'))),
#  'Bosque County, Texas': censusgeo((('state', '48'), ('county', '035'))),
#  'Bowie County, Texas': censusgeo((('state', '48'), ('county', '037'))),
#  'Brazoria County, Texas': censusgeo((('state', '48'), ('county', '039'))),
#  'Brazos County, Texas': censusgeo((('state', '48'), ('county', '041'))),
#  'Brewster County, Texas': censusgeo((('state', '48'), ('county', '043'))),
#  'Briscoe County, Texas': censusgeo((('state', '48'), ('county', '045'))),
#  'Brooks County, Texas': censusgeo((('state', '48'), ('county', '047'))),
#  'Brown County, Texas': censusgeo((('state', '48'), ('county', '049'))),
#  'Burleson County, Texas': censusgeo((('state', '48'), ('county', '051'))),
#  'Burnet County, Texas': censusgeo((('state', '48'), ('county', '053'))),
#  'Caldwell County, Texas': censusgeo((('state', '48'), ('county', '055'))),
#  'Calhoun County, Texas': censusgeo((('state', '48'), ('county', '057'))),
#  'Callahan County, Texas': censusgeo((('state', '48'), ('county', '059'))),
#  'Cameron County, Texas': censusgeo((('state', '48'), ('county', '061'))),
#  'Camp County, Texas': censusgeo((('state', '48'), ('county', '063'))),
#  'Carson County, Texas': censusgeo((('state', '48'), ('county', '065'))),
#  'Cass County, Texas': censusgeo((('state', '48'), ('county', '067'))),
#  'Castro County, Texas': censusgeo((('state', '48'), ('county', '069'))),
#  'Chambers County, Texas': censusgeo((('state', '48'), ('county', '071'))),
#  'Cherokee County, Texas': censusgeo((('state', '48'), ('county', '073'))),
#  'Childress County, Texas': censusgeo((('state', '48'), ('county', '075'))),
#  'Clay County, Texas': censusgeo((('state', '48'), ('county', '077'))),
#  'Cochran County, Texas': censusgeo((('state', '48'), ('county', '079'))),
#  'Coke County, Texas': censusgeo((('state', '48'), ('county', '081'))),
#  'Coleman County, Texas': censusgeo((('state', '48'), ('county', '083'))),
#  'Collin County, Texas': censusgeo((('state', '48'), ('county', '085'))),
#  'Collingsworth County, Texas': censusgeo((('state', '48'), ('county', '087'))),
#  'Colorado County, Texas': censusgeo((('state', '48'), ('county', '089'))),
#  'Comal County, Texas': censusgeo((('state', '48'), ('county', '091'))),
#  'Comanche County, Texas': censusgeo((('state', '48'), ('county', '093'))),
#  'Concho County, Texas': censusgeo((('state', '48'), ('county', '095'))),
#  'Cooke County, Texas': censusgeo((('state', '48'), ('county', '097'))),
#  'Coryell County, Texas': censusgeo((('state', '48'), ('county', '099'))),
#  'Cottle County, Texas': censusgeo((('state', '48'), ('county', '101'))),
#  'Crane County, Texas': censusgeo((('state', '48'), ('county', '103'))),
#  'Crockett County, Texas': censusgeo((('state', '48'), ('county', '105'))),
#  'Crosby County, Texas': censusgeo((('state', '48'), ('county', '107'))),
#  'Culberson County, Texas': censusgeo((('state', '48'), ('county', '109'))),
#  'Dallam County, Texas': censusgeo((('state', '48'), ('county', '111'))),
#  'Dallas County, Texas': censusgeo((('state', '48'), ('county', '113'))),
#  'Dawson County, Texas': censusgeo((('state', '48'), ('county', '115'))),
#  'Deaf Smith County, Texas': censusgeo((('state', '48'), ('county', '117'))),
#  'Delta County, Texas': censusgeo((('state', '48'), ('county', '119'))),
#  'Denton County, Texas': censusgeo((('state', '48'), ('county', '121'))),
#  'DeWitt County, Texas': censusgeo((('state', '48'), ('county', '123'))),
#  'Dickens County, Texas': censusgeo((('state', '48'), ('county', '125'))),
#  'Dimmit County, Texas': censusgeo((('state', '48'), ('county', '127'))),
#  'Donley County, Texas': censusgeo((('state', '48'), ('county', '129'))),
#  'Duval County, Texas': censusgeo((('state', '48'), ('county', '131'))),
#  'Eastland County, Texas': censusgeo((('state', '48'), ('county', '133'))),
#  'Ector County, Texas': censusgeo((('state', '48'), ('county', '135'))),
#  'Edwards County, Texas': censusgeo((('state', '48'), ('county', '137'))),
#  'Ellis County, Texas': censusgeo((('state', '48'), ('county', '139'))),
#  'El Paso County, Texas': censusgeo((('state', '48'), ('county', '141'))),
#  'Erath County, Texas': censusgeo((('state', '48'), ('county', '143'))),
#  'Falls County, Texas': censusgeo((('state', '48'), ('county', '145'))),
#  'Fannin County, Texas': censusgeo((('state', '48'), ('county', '147'))),
#  'Fayette County, Texas': censusgeo((('state', '48'), ('county', '149'))),
#  'Fisher County, Texas': censusgeo((('state', '48'), ('county', '151'))),
#  'Floyd County, Texas': censusgeo((('state', '48'), ('county', '153'))),
#  'Foard County, Texas': censusgeo((('state', '48'), ('county', '155'))),
#  'Fort Bend County, Texas': censusgeo((('state', '48'), ('county', '157'))),
#  'Franklin County, Texas': censusgeo((('state', '48'), ('county', '159'))),
#  'Freestone County, Texas': censusgeo((('state', '48'), ('county', '161'))),
#  'Frio County, Texas': censusgeo((('state', '48'), ('county', '163'))),
#  'Gaines County, Texas': censusgeo((('state', '48'), ('county', '165'))),
#  'Galveston County, Texas': censusgeo((('state', '48'), ('county', '167'))),
#  'Garza County, Texas': censusgeo((('state', '48'), ('county', '169'))),
#  'Gillespie County, Texas': censusgeo((('state', '48'), ('county', '171'))),
#  'Glasscock County, Texas': censusgeo((('state', '48'), ('county', '173'))),
#  'Goliad County, Texas': censusgeo((('state', '48'), ('county', '175'))),
#  'Gonzales County, Texas': censusgeo((('state', '48'), ('county', '177'))),
#  'Gray County, Texas': censusgeo((('state', '48'), ('county', '179'))),
#  'Grayson County, Texas': censusgeo((('state', '48'), ('county', '181'))),
#  'Gregg County, Texas': censusgeo((('state', '48'), ('county', '183'))),
#  'Grimes County, Texas': censusgeo((('state', '48'), ('county', '185'))),
#  'Guadalupe County, Texas': censusgeo((('state', '48'), ('county', '187'))),
#  'Hale County, Texas': censusgeo((('state', '48'), ('county', '189'))),
#  'Hall County, Texas': censusgeo((('state', '48'), ('county', '191'))),
#  'Hamilton County, Texas': censusgeo((('state', '48'), ('county', '193'))),
#  'Hansford County, Texas': censusgeo((('state', '48'), ('county', '195'))),
#  'Hardeman County, Texas': censusgeo((('state', '48'), ('county', '197'))),
#  'Hardin County, Texas': censusgeo((('state', '48'), ('county', '199'))),
#  'Harris County, Texas': censusgeo((('state', '48'), ('county', '201'))),
#  'Harrison County, Texas': censusgeo((('state', '48'), ('county', '203'))),
#  'Hartley County, Texas': censusgeo((('state', '48'), ('county', '205'))),
#  'Haskell County, Texas': censusgeo((('state', '48'), ('county', '207'))),
#  'Hays County, Texas': censusgeo((('state', '48'), ('county', '209'))),
#  'Hemphill County, Texas': censusgeo((('state', '48'), ('county', '211'))),
#  'Henderson County, Texas': censusgeo((('state', '48'), ('county', '213'))),
#  'Hidalgo County, Texas': censusgeo((('state', '48'), ('county', '215'))),
#  'Hill County, Texas': censusgeo((('state', '48'), ('county', '217'))),
#  'Hockley County, Texas': censusgeo((('state', '48'), ('county', '219'))),
#  'Hood County, Texas': censusgeo((('state', '48'), ('county', '221'))),
#  'Hopkins County, Texas': censusgeo((('state', '48'), ('county', '223'))),
#  'Houston County, Texas': censusgeo((('state', '48'), ('county', '225'))),
#  'Howard County, Texas': censusgeo((('state', '48'), ('county', '227'))),
#  'Hudspeth County, Texas': censusgeo((('state', '48'), ('county', '229'))),
#  'Hunt County, Texas': censusgeo((('state', '48'), ('county', '231'))),
#  'Hutchinson County, Texas': censusgeo((('state', '48'), ('county', '233'))),
#  'Irion County, Texas': censusgeo((('state', '48'), ('county', '235'))),
#  'Jack County, Texas': censusgeo((('state', '48'), ('county', '237'))),
#  'Jackson County, Texas': censusgeo((('state', '48'), ('county', '239'))),
#  'Jasper County, Texas': censusgeo((('state', '48'), ('county', '241'))),
#  'Jeff Davis County, Texas': censusgeo((('state', '48'), ('county', '243'))),
#  'Jefferson County, Texas': censusgeo((('state', '48'), ('county', '245'))),
#  'Jim Hogg County, Texas': censusgeo((('state', '48'), ('county', '247'))),
#  'Jim Wells County, Texas': censusgeo((('state', '48'), ('county', '249'))),
#  'Johnson County, Texas': censusgeo((('state', '48'), ('county', '251'))),
#  'Jones County, Texas': censusgeo((('state', '48'), ('county', '253'))),
#  'Karnes County, Texas': censusgeo((('state', '48'), ('county', '255'))),
#  'Kaufman County, Texas': censusgeo((('state', '48'), ('county', '257'))),
#  'Kendall County, Texas': censusgeo((('state', '48'), ('county', '259'))),
#  'Kenedy County, Texas': censusgeo((('state', '48'), ('county', '261'))),
#  'Kent County, Texas': censusgeo((('state', '48'), ('county', '263'))),
#  'Kerr County, Texas': censusgeo((('state', '48'), ('county', '265'))),
#  'Kimble County, Texas': censusgeo((('state', '48'), ('county', '267'))),
#  'King County, Texas': censusgeo((('state', '48'), ('county', '269'))),
#  'Kinney County, Texas': censusgeo((('state', '48'), ('county', '271'))),
#  'Kleberg County, Texas': censusgeo((('state', '48'), ('county', '273'))),
#  'Knox County, Texas': censusgeo((('state', '48'), ('county', '275'))),
#  'Lamar County, Texas': censusgeo((('state', '48'), ('county', '277'))),
#  'Lamb County, Texas': censusgeo((('state', '48'), ('county', '279'))),
#  'Lampasas County, Texas': censusgeo((('state', '48'), ('county', '281'))),
#  'La Salle County, Texas': censusgeo((('state', '48'), ('county', '283'))),
#  'Lavaca County, Texas': censusgeo((('state', '48'), ('county', '285'))),
#  'Lee County, Texas': censusgeo((('state', '48'), ('county', '287'))),
#  'Leon County, Texas': censusgeo((('state', '48'), ('county', '289'))),
#  'Liberty County, Texas': censusgeo((('state', '48'), ('county', '291'))),
#  'Limestone County, Texas': censusgeo((('state', '48'), ('county', '293'))),
#  'Lipscomb County, Texas': censusgeo((('state', '48'), ('county', '295'))),
#  'Live Oak County, Texas': censusgeo((('state', '48'), ('county', '297'))),
#  'Llano County, Texas': censusgeo((('state', '48'), ('county', '299'))),
#  'Loving County, Texas': censusgeo((('state', '48'), ('county', '301'))),
#  'Lubbock County, Texas': censusgeo((('state', '48'), ('county', '303'))),
#  'Lynn County, Texas': censusgeo((('state', '48'), ('county', '305'))),
#  'McCulloch County, Texas': censusgeo((('state', '48'), ('county', '307'))),
#  'McLennan County, Texas': censusgeo((('state', '48'), ('county', '309'))),
#  'McMullen County, Texas': censusgeo((('state', '48'), ('county', '311'))),
#  'Madison County, Texas': censusgeo((('state', '48'), ('county', '313'))),
#  'Marion County, Texas': censusgeo((('state', '48'), ('county', '315'))),
#  'Martin County, Texas': censusgeo((('state', '48'), ('county', '317'))),
#  'Mason County, Texas': censusgeo((('state', '48'), ('county', '319'))),
#  'Matagorda County, Texas': censusgeo((('state', '48'), ('county', '321'))),
#  'Maverick County, Texas': censusgeo((('state', '48'), ('county', '323'))),
#  'Medina County, Texas': censusgeo((('state', '48'), ('county', '325'))),
#  'Menard County, Texas': censusgeo((('state', '48'), ('county', '327'))),
#  'Midland County, Texas': censusgeo((('state', '48'), ('county', '329'))),
#  'Milam County, Texas': censusgeo((('state', '48'), ('county', '331'))),
#  'Mills County, Texas': censusgeo((('state', '48'), ('county', '333'))),
#  'Mitchell County, Texas': censusgeo((('state', '48'), ('county', '335'))),
#  'Montague County, Texas': censusgeo((('state', '48'), ('county', '337'))),
#  'Montgomery County, Texas': censusgeo((('state', '48'), ('county', '339'))),
#  'Moore County, Texas': censusgeo((('state', '48'), ('county', '341'))),
#  'Morris County, Texas': censusgeo((('state', '48'), ('county', '343'))),
#  'Motley County, Texas': censusgeo((('state', '48'), ('county', '345'))),
#  'Nacogdoches County, Texas': censusgeo((('state', '48'), ('county', '347'))),
#  'Navarro County, Texas': censusgeo((('state', '48'), ('county', '349'))),
#  'Newton County, Texas': censusgeo((('state', '48'), ('county', '351'))),
#  'Nolan County, Texas': censusgeo((('state', '48'), ('county', '353'))),
#  'Nueces County, Texas': censusgeo((('state', '48'), ('county', '355'))),
#  'Ochiltree County, Texas': censusgeo((('state', '48'), ('county', '357'))),
#  'Oldham County, Texas': censusgeo((('state', '48'), ('county', '359'))),
#  'Orange County, Texas': censusgeo((('state', '48'), ('county', '361'))),
#  'Palo Pinto County, Texas': censusgeo((('state', '48'), ('county', '363'))),
#  'Panola County, Texas': censusgeo((('state', '48'), ('county', '365'))),
#  'Parker County, Texas': censusgeo((('state', '48'), ('county', '367'))),
#  'Parmer County, Texas': censusgeo((('state', '48'), ('county', '369'))),
#  'Pecos County, Texas': censusgeo((('state', '48'), ('county', '371'))),
#  'Polk County, Texas': censusgeo((('state', '48'), ('county', '373'))),
#  'Potter County, Texas': censusgeo((('state', '48'), ('county', '375'))),
#  'Presidio County, Texas': censusgeo((('state', '48'), ('county', '377'))),
#  'Rains County, Texas': censusgeo((('state', '48'), ('county', '379'))),
#  'Randall County, Texas': censusgeo((('state', '48'), ('county', '381'))),
#  'Reagan County, Texas': censusgeo((('state', '48'), ('county', '383'))),
#  'Real County, Texas': censusgeo((('state', '48'), ('county', '385'))),
#  'Red River County, Texas': censusgeo((('state', '48'), ('county', '387'))),
#  'Reeves County, Texas': censusgeo((('state', '48'), ('county', '389'))),
#  'Refugio County, Texas': censusgeo((('state', '48'), ('county', '391'))),
#  'Roberts County, Texas': censusgeo((('state', '48'), ('county', '393'))),
#  'Robertson County, Texas': censusgeo((('state', '48'), ('county', '395'))),
#  'Rockwall County, Texas': censusgeo((('state', '48'), ('county', '397'))),
#  'Runnels County, Texas': censusgeo((('state', '48'), ('county', '399'))),
#  'Rusk County, Texas': censusgeo((('state', '48'), ('county', '401'))),
#  'Sabine County, Texas': censusgeo((('state', '48'), ('county', '403'))),
#  'San Augustine County, Texas': censusgeo((('state', '48'), ('county', '405'))),
#  'San Jacinto County, Texas': censusgeo((('state', '48'), ('county', '407'))),
#  'San Patricio County, Texas': censusgeo((('state', '48'), ('county', '409'))),
#  'San Saba County, Texas': censusgeo((('state', '48'), ('county', '411'))),
#  'Schleicher County, Texas': censusgeo((('state', '48'), ('county', '413'))),
#  'Scurry County, Texas': censusgeo((('state', '48'), ('county', '415'))),
#  'Shackelford County, Texas': censusgeo((('state', '48'), ('county', '417'))),
#  'Shelby County, Texas': censusgeo((('state', '48'), ('county', '419'))),
#  'Sherman County, Texas': censusgeo((('state', '48'), ('county', '421'))),
#  'Smith County, Texas': censusgeo((('state', '48'), ('county', '423'))),
#  'Somervell County, Texas': censusgeo((('state', '48'), ('county', '425'))),
#  'Starr County, Texas': censusgeo((('state', '48'), ('county', '427'))),
#  'Stephens County, Texas': censusgeo((('state', '48'), ('county', '429'))),
#  'Sterling County, Texas': censusgeo((('state', '48'), ('county', '431'))),
#  'Stonewall County, Texas': censusgeo((('state', '48'), ('county', '433'))),
#  'Sutton County, Texas': censusgeo((('state', '48'), ('county', '435'))),
#  'Swisher County, Texas': censusgeo((('state', '48'), ('county', '437'))),
#  'Tarrant County, Texas': censusgeo((('state', '48'), ('county', '439'))),
#  'Taylor County, Texas': censusgeo((('state', '48'), ('county', '441'))),
#  'Terrell County, Texas': censusgeo((('state', '48'), ('county', '443'))),
#  'Terry County, Texas': censusgeo((('state', '48'), ('county', '445'))),
#  'Throckmorton County, Texas': censusgeo((('state', '48'), ('county', '447'))),
#  'Titus County, Texas': censusgeo((('state', '48'), ('county', '449'))),
#  'Tom Green County, Texas': censusgeo((('state', '48'), ('county', '451'))),
#  'Travis County, Texas': censusgeo((('state', '48'), ('county', '453'))),
#  'Trinity County, Texas': censusgeo((('state', '48'), ('county', '455'))),
#  'Tyler County, Texas': censusgeo((('state', '48'), ('county', '457'))),
#  'Upshur County, Texas': censusgeo((('state', '48'), ('county', '459'))),
#  'Upton County, Texas': censusgeo((('state', '48'), ('county', '461'))),
#  'Uvalde County, Texas': censusgeo((('state', '48'), ('county', '463'))),
#  'Val Verde County, Texas': censusgeo((('state', '48'), ('county', '465'))),
#  'Van Zandt County, Texas': censusgeo((('state', '48'), ('county', '467'))),
#  'Victoria County, Texas': censusgeo((('state', '48'), ('county', '469'))),
#  'Walker County, Texas': censusgeo((('state', '48'), ('county', '471'))),
#  'Waller County, Texas': censusgeo((('state', '48'), ('county', '473'))),
#  'Ward County, Texas': censusgeo((('state', '48'), ('county', '475'))),
#  'Washington County, Texas': censusgeo((('state', '48'), ('county', '477'))),
#  'Webb County, Texas': censusgeo((('state', '48'), ('county', '479'))),
#  'Wharton County, Texas': censusgeo((('state', '48'), ('county', '481'))),
#  'Wheeler County, Texas': censusgeo((('state', '48'), ('county', '483'))),
#  'Wichita County, Texas': censusgeo((('state', '48'), ('county', '485'))),
#  'Wilbarger County, Texas': censusgeo((('state', '48'), ('county', '487'))),
#  'Willacy County, Texas': censusgeo((('state', '48'), ('county', '489'))),
#  'Williamson County, Texas': censusgeo((('state', '48'), ('county', '491'))),
#  'Wilson County, Texas': censusgeo((('state', '48'), ('county', '493'))),
#  'Winkler County, Texas': censusgeo((('state', '48'), ('county', '495'))),
#  'Wise County, Texas': censusgeo((('state', '48'), ('county', '497'))),
#  'Wood County, Texas': censusgeo((('state', '48'), ('county', '499'))),
#  'Yoakum County, Texas': censusgeo((('state', '48'), ('county', '501'))),
#  'Young County, Texas': censusgeo((('state', '48'), ('county', '503'))),
#  'Zapata County, Texas': censusgeo((('state', '48'), ('county', '505'))),
#  'Zavala County, Texas': censusgeo((('state', '48'), ('county', '507')))}

# %%
zavalaTX_data = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '48'), ('county', '507')]),
                             ['B03002_012E', 'B01003_001E'])

# %%
zavalaTX_data['Percent_Hispanic/Latino']= zavalaTX_data.B03002_012E/zavalaTX_data.B01003_001E *100
zavalaTX_data.head()
# Out:
#                                                     B03002_012E  B01003_001E  \
# Zavala County, Texas: Summary level: 050, state...        11216        12060
#
#                                                     Percent_Hispanic/Latino
# Zavala County, Texas: Summary level: 050, state...                93.001658
